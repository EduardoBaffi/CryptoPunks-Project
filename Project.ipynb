# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ### CYBERPUNKS

# %%
# Read the dataset about cyberpunks parameters
cyberpunks_df=pd.read_csv('cryptopunks.csv')
cyberpunks_df
# Out:
#       Unnamed: 0  rarity_rank   tipus            skin  \
# 0              0         2023  Female     Mid-skinned
# 1              1         4352    Male    Dark-skinned
# 2              2         8090  Female   Light-skinned
# 3              3         7896    Male    Dark-skinned
# 4              4         7332    Male     Mid-skinned
# ...          ...          ...     ...             ...
# 9995        9995         2466  Female  Albino-skinned
# 9996        9996         4323    Male   Light-skinned
# 9997        9997          498  Zombie  Zombie-skinned
# 9998        9998         1271  Female     Mid-skinned
# 9999        9999         9233  Female    Dark-skinned
#
#                                                  traits  traits_count  \
# 0     Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 1                                         Mohawk, Smile             2
# 2                                             Wild Hair             1
# 3                         Nerd Glasses, Pipe, Wild Hair             3
# 4                  Big Shades, Earring, Goat, Wild Hair             4
# ...                                                 ...           ...
# 9995              Purple Eye Shadow, Straight Hair Dark             2
# 9996              Cigarette, Crazy Hair, Earring, Smile             4
# 9997                           Cap Forward, Front Beard             2
# 9998  Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 9999                               Mohawk, Nerd Glasses             2
#
#          owner
# 0     0xE08c32
# 1     0xB88F61
# 2     0x897aEA
# 3     0xC352B5
# 4     0xC352B5
# ...        ...
# 9995  0x758353
# 9996  0xA9bFA9
# 9997  0x944D32
# 9998  0xef764B
# 9999  0x0A383e
#
# [10000 rows x 7 columns]

# %%
cyberpunks_df.drop(cyberpunks_df.columns[[0]], axis=1, inplace=True)
cyberpunks_df
# Out:
#       rarity_rank   tipus            skin  \
# 0            2023  Female     Mid-skinned
# 1            4352    Male    Dark-skinned
# 2            8090  Female   Light-skinned
# 3            7896    Male    Dark-skinned
# 4            7332    Male     Mid-skinned
# ...           ...     ...             ...
# 9995         2466  Female  Albino-skinned
# 9996         4323    Male   Light-skinned
# 9997          498  Zombie  Zombie-skinned
# 9998         1271  Female     Mid-skinned
# 9999         9233  Female    Dark-skinned
#
#                                                  traits  traits_count  \
# 0     Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 1                                         Mohawk, Smile             2
# 2                                             Wild Hair             1
# 3                         Nerd Glasses, Pipe, Wild Hair             3
# 4                  Big Shades, Earring, Goat, Wild Hair             4
# ...                                                 ...           ...
# 9995              Purple Eye Shadow, Straight Hair Dark             2
# 9996              Cigarette, Crazy Hair, Earring, Smile             4
# 9997                           Cap Forward, Front Beard             2
# 9998  Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 9999                               Mohawk, Nerd Glasses             2
#
#          owner
# 0     0xE08c32
# 1     0xB88F61
# 2     0x897aEA
# 3     0xC352B5
# 4     0xC352B5
# ...        ...
# 9995  0x758353
# 9996  0xA9bFA9
# 9997  0x944D32
# 9998  0xef764B
# 9999  0x0A383e
#
# [10000 rows x 6 columns]

# %%
cyberpunks_df.isnull().sum()
# Out:
# rarity_rank     0
# tipus           0
# skin            0
# traits          8
# traits_count    0
# owner           0
# dtype: int64

# %%
cyberpunks_df.duplicated().sum()
# Out:
# 0

# %%
cyberpunks_df[cyberpunks_df['traits'].isnull()]
# Out:
#       rarity_rank   tipus            skin traits  traits_count     owner
# 281             7    Male   Light-skinned    NaN             1  0x6611fE
# 510             9    Male     Mid-skinned    NaN             1  0x78f026
# 641             6  Female   Light-skinned    NaN             1  0x69021A
# 741             5    Male    Dark-skinned    NaN             1  0xB813c6
# 1050            8  Female     Mid-skinned    NaN             1  0x69021A
# 2204            4  Female    Dark-skinned    NaN             1  0x577eBC
# 3307            3    Male  Albino-skinned    NaN             1  0x7224a1
# 6487            2  Female  Albino-skinned    NaN             1  0x4d8E16

# %%
cyberpunks_df.fillna(0, inplace=True)

# %%
cyberpunks_df.isnull().sum()
# Out:
# rarity_rank     0
# tipus           0
# skin            0
# traits          0
# traits_count    0
# owner           0
# dtype: int64

# %%
cyberpunks_df.loc[[281,510,641,741,1050,2204,3307,6487],'traits_count']=0
cyberpunks_df.loc[[281,510,641,741,1050,2204,3307,6487]]
# Out:
#       rarity_rank   tipus            skin traits  traits_count     owner
# 281             7    Male   Light-skinned      0             0  0x6611fE
# 510             9    Male     Mid-skinned      0             0  0x78f026
# 641             6  Female   Light-skinned      0             0  0x69021A
# 741             5    Male    Dark-skinned      0             0  0xB813c6
# 1050            8  Female     Mid-skinned      0             0  0x69021A
# 2204            4  Female    Dark-skinned      0             0  0x577eBC
# 3307            3    Male  Albino-skinned      0             0  0x7224a1
# 6487            2  Female  Albino-skinned      0             0  0x4d8E16

# %%
cyberpunks_df.describe()
# Out:
#        rarity_rank  traits_count
# count  10000.00000  10000.000000
# mean    5000.50000      2.817500
# std     2886.89568      0.912073
# min        1.00000      0.000000
# 25%     2500.75000      2.000000
# 50%     5000.50000      3.000000
# 75%     7500.25000      3.000000
# max    10000.00000      9.000000

# %%
cyberpunks_df.traits_count.value_counts()
# Out:
# 3    4280
# 2    3535
# 4    1371
# 5     404
# 1     333
# 6      57
# 7      11
# 0       8
# 9       1
# Name: traits_count, dtype: int64

# %% [markdown]
# #### tipus parameter

# %%
tipus_df=pd.DataFrame(cyberpunks_df.tipus.value_counts())
tipus_df
# Out:
#         tipus
# Male     6039
# Female   3840
# Zombie     88
# Ape        24
# Alien       9

# %%
tipus_df.index
# Out:
# Index(['Male', 'Female', 'Zombie', 'Ape', 'Alien'], dtype='object')

# %%
tipus_df.columns
# Out:
# Index(['tipus'], dtype='object')

# %%
tipus_df.index=tipus_df.index.astype(str)

# %%
import squarify

sns.set(rc={'figure.figsize':(15,8)})
squarify.plot(sizes=tipus_df.tipus, label=tipus_df.index, color = ['green', 'blue', 'red', 'gray','yellow'] , alpha=.4)
plt.axis('off')
plt.show()

# %%
tipus_df.describe()
# Out:
#              tipus
# count     5.000000
# mean   2000.000000
# std    2793.900589
# min       9.000000
# 25%      24.000000
# 50%      88.000000
# 75%    3840.000000
# max    6039.000000

# %%
tipusPercent_df=(tipus_df/((tipus_df.sum())/100))
tipusPercent_df=tipusPercent_df.rename(columns={'tipus':'tipus(%)'})
tipusPercent_df
# Out:
#         tipus(%)
# Male       60.39
# Female     38.40
# Zombie      0.88
# Ape         0.24
# Alien       0.09

# %% [markdown]
# #### traits_count parameter

# %%
traitsCount_df=pd.DataFrame(cyberpunks_df.traits_count.value_counts())
traitsCount_df
# Out:
#    traits_count
# 3          4280
# 2          3535
# 4          1371
# 5           404
# 1           333
# 6            57
# 7            11
# 0             8
# 9             1

# %%
traitsCount_df.reset_index(level=0, inplace=True)
traitsCount_df = traitsCount_df.rename(columns={'index':'traits_total'})
traitsCount_df
# Out:
#    traits_total  traits_count
# 0             3          4280
# 1             2          3535
# 2             4          1371
# 3             5           404
# 4             1           333
# 5             6            57
# 6             7            11
# 7             0             8
# 8             9             1

# %%
my_range=range(0,len(traitsCount_df.traits_total))
sns.set(rc={'figure.figsize':(9,6)})
plt.stem(traitsCount_df['traits_count'])
plt.xticks(my_range, traitsCount_df['traits_total'])
plt.title("Total of Cyberpunks X Number of Traits")
plt.xlabel('Number of Traits')
plt.ylabel('Total of Cyberpunks')

plt.show()

# %% [markdown]
# #### skin parameter

# %%
skin_df=pd.DataFrame(cyberpunks_df.skin.value_counts())
skin_df
# Out:
#                 skin
# Mid-skinned     3031
# Light-skinned   3006
# Dark-skinned    2824
# Albino-skinned  1018
# Zombie-skinned    88
# Ape-skinned       24
# Alien-skinned      9

# %%
skinPercent_df=(skin_df/((skin_df.sum())/100))
skinPercent_df=skinPercent_df.rename(columns={'skin':'skin(%)'})
skinPercent_df
# Out:
#                 skin(%)
# Mid-skinned       30.31
# Light-skinned     30.06
# Dark-skinned      28.24
# Albino-skinned    10.18
# Zombie-skinned     0.88
# Ape-skinned        0.24
# Alien-skinned      0.09

# %%
skinList = ("Midskinned,"*3031)+("Lightskinned,"*3006)+("Darkskinned,"*2824)+("Albinoskinned,"*1018)+("Zombieskinned,"*88)+("Apeskinned,"*24)+("Alienskinned,"*9)
skinList
# Out:
# 'Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midskinned,Midski ...

# %%
list
# Out:
# list

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=skinList

# Create the wordcloud object
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# #### rarity parameter

# %%
rarity_df=pd.DataFrame(cyberpunks_df.rarity_rank.value_counts())
rarity_df
rarity_df.describe()
# Out:
#        rarity_rank
# count      10000.0
# mean           1.0
# std            0.0
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0

# %%
import seaborn as sns

sns.set(style="whitegrid")
ax = sns.boxplot(x=cyberpunks_df["rarity_rank"], color='lightblue', fliersize=5,  orient='v', linewidth=1 , width=0.3)

# %% [markdown]
# #### Reltions between parameters

# %%
# Create data
y = cyberpunks_df.rarity_rank
x = cyberpunks_df.traits_count
colors = 'Blue'
area = np.pi*10

# Plot
plt.scatter(x, y, s=area, c=colors, alpha=0.4, edgecolors='black')

plt.title('Rarity vs Traits')
plt.xlabel('Number of Traits')
plt.ylabel('Rarity')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(6,4))
cor = cyberpunks_df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
print(cyberpunks_df[["rarity_rank","traits_count"]].corr())
# Out:
#               rarity_rank  traits_count
# rarity_rank      1.000000     -0.114225
# traits_count    -0.114225      1.000000

# %%
cyberpunks_df.head(1)
# Out:
#    rarity_rank   tipus         skin  \
# 0         2023  Female  Mid-skinned
#
#                                               traits  traits_count     owner
# 0  Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4  0xE08c32

# %%
cyberpunks_df.groupby("tipus")["traits_count"].mean()
# Out:
# tipus
# Alien     1.888889
# Ape       1.750000
# Female    2.840885
# Male      2.815864
# Zombie    2.295455
# Name: traits_count, dtype: float64

# %%
cyberpunks_df.groupby("skin")["traits_count"].mean()
# Out:
# skin
# Albino-skinned    2.634578
# Alien-skinned     1.888889
# Ape-skinned       1.750000
# Dark-skinned      2.837465
# Light-skinned     2.826680
# Mid-skinned       2.877598
# Zombie-skinned    2.295455
# Name: traits_count, dtype: float64

# %%
tipuSkin_df=pd.DataFrame(cyberpunks_df.groupby(["tipus","skin"])["traits_count"].count())
tipuSkin_df
# Out:
#                        traits_count
# tipus  skin
# Alien  Alien-skinned              9
# Ape    Ape-skinned               24
# Female Albino-skinned           420
#        Dark-skinned            1101
#        Light-skinned           1145
#        Mid-skinned             1174
# Male   Albino-skinned           598
#        Dark-skinned            1723
#        Light-skinned           1861
#        Mid-skinned             1857
# Zombie Zombie-skinned            88

# %%
tipuSkin_df.reset_index(level=0, inplace=True)
tipuSkin_df
# Out:
#                  tipus  traits_count
# skin
# Alien-skinned    Alien             9
# Ape-skinned        Ape            24
# Albino-skinned  Female           420
# Dark-skinned    Female          1101
# Light-skinned   Female          1145
# Mid-skinned     Female          1174
# Albino-skinned    Male           598
# Dark-skinned      Male          1723
# Light-skinned     Male          1861
# Mid-skinned       Male          1857
# Zombie-skinned  Zombie            88

# %%
tipuSkin_df.reset_index(level=0, inplace=True)

# %%
tipuSkin_df
# Out:
#               skin   tipus  traits_count
# 0    Alien-skinned   Alien             9
# 1      Ape-skinned     Ape            24
# 2   Albino-skinned  Female           420
# 3     Dark-skinned  Female          1101
# 4    Light-skinned  Female          1145
# 5      Mid-skinned  Female          1174
# 6   Albino-skinned    Male           598
# 7     Dark-skinned    Male          1723
# 8    Light-skinned    Male          1861
# 9      Mid-skinned    Male          1857
# 10  Zombie-skinned  Zombie            88

# %%
tipuSkin_df.plot(x="tipus", y="skin".count(), kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-263-db891e851d1e> in <module>
# ----> 1 tipuSkin_df.plot(x="tipus", y="skin".count(), kind="bar")
#
# TypeError: count() takes at least 1 argument (0 given)

# %%
sns.catplot(data=cyberpunks_df,kind='count',x='tipus',hue='skin', aspect=2.2)
plt.savefig('tipusSkin_plot.png')

# %%
import dataframe_image as dfi
dfi.export(tipuSkin_df, 'relation_tupis_skin_df.png')

# %%
pd.DataFrame(cyberpunks_df.groupby("tipus")["rarity_rank"].mean())
# Out:
#         rarity_rank
# tipus
# Alien     14.000000
# Ape       41.500000
# Female  4314.186458
# Male    5529.366948
# Zombie   517.670455

# %%
cyberpunks_df.groupby("skin")["rarity_rank"].mean()
# Out:
# skin
# Albino-skinned    5352.840864
# Alien-skinned       14.000000
# Ape-skinned         41.500000
# Dark-skinned      5028.654391
# Light-skinned     5026.862941
# Mid-skinned       5014.008908
# Zombie-skinned     517.670455
# Name: rarity_rank, dtype: float64

# %% [markdown]
# ### TRANSACTIONS

# %%
# Read the dataset about cyberpunks transactions
transactions_df=pd.read_csv('Transactions_clean.csv')
transactions_df
# Out:
#         Unnamed: 0  idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 0                0              0      0xe73a1d   Bid Withdrawn             0
# 1                1              1      0xe73a1d             Bid             0
# 2                2              2      0x2e5e22   Bid Withdrawn             0
# 3                3              3      0x2e5e22             Bid             0
# 4                4              4      0x2e5e22   Bid Withdrawn             0
# ...            ...            ...           ...             ...           ...
# 161280      161329         161329      0xa0a59c             Bid          9999
# 161281      161330         161330      0x717403             Bid          9999
# 161282      161331         161331      ddaavvee             Bid          9999
# 161283      161332         161332      0x5b098b             Bid          9999
# 161284      161333         161333      0x7e2d1c         Claimed          9999
#
#            Owner  Reciever  AmountETH  AmountDollar        Date
# 0       0xe73a1d       NaN     321.00     1260000.0  2021-09-04
# 1       0xe73a1d       NaN     321.00     1140000.0  2021-09-01
# 2       0x2e5e22       NaN     320.00     1110000.0  2021-09-01
# 3       0x2e5e22       NaN     320.00     1100000.0  2021-09-01
# 4       0x2e5e22       NaN     263.00      904481.0  2021-09-01
# ...          ...       ...        ...           ...         ...
# 161280  0xa0a59c       NaN       0.25          69.0  2017-07-03
# 161281  0x717403       NaN       0.20          51.0  2017-06-26
# 161282  ddaavvee       NaN       0.20          65.0  2017-06-23
# 161283  0x5b098b       NaN       0.15          50.0  2017-06-23
# 161284       NaN  0x7e2d1c       0.00           0.0  2017-06-23
#
# [161285 rows x 10 columns]

# %%
transactions_df.drop(transactions_df.columns[[0]], axis=1, inplace=True)
transactions_df
# Out:
#         idTransaction idPropietario TypeTransaction  idCryptoPunk     Owner  \
# 0                   0      0xe73a1d   Bid Withdrawn             0  0xe73a1d
# 1                   1      0xe73a1d             Bid             0  0xe73a1d
# 2                   2      0x2e5e22   Bid Withdrawn             0  0x2e5e22
# 3                   3      0x2e5e22             Bid             0  0x2e5e22
# 4                   4      0x2e5e22   Bid Withdrawn             0  0x2e5e22
# ...               ...           ...             ...           ...       ...
# 161280         161329      0xa0a59c             Bid          9999  0xa0a59c
# 161281         161330      0x717403             Bid          9999  0x717403
# 161282         161331      ddaavvee             Bid          9999  ddaavvee
# 161283         161332      0x5b098b             Bid          9999  0x5b098b
# 161284         161333      0x7e2d1c         Claimed          9999       NaN
#
#         Reciever  AmountETH  AmountDollar        Date
# 0            NaN     321.00     1260000.0  2021-09-04
# 1            NaN     321.00     1140000.0  2021-09-01
# 2            NaN     320.00     1110000.0  2021-09-01
# 3            NaN     320.00     1100000.0  2021-09-01
# 4            NaN     263.00      904481.0  2021-09-01
# ...          ...        ...           ...         ...
# 161280       NaN       0.25          69.0  2017-07-03
# 161281       NaN       0.20          51.0  2017-06-26
# 161282       NaN       0.20          65.0  2017-06-23
# 161283       NaN       0.15          50.0  2017-06-23
# 161284  0x7e2d1c       0.00           0.0  2017-06-23
#
# [161285 rows x 9 columns]

# %%
transact_df = transactions_df.copy()

# %%
typesTransact = pd.DataFrame(transact_df.TypeTransaction.value_counts())
typesTransact
# Out:
#                  TypeTransaction
# Offered                    62822
# Bid                        25923
# Sold                       18425
# Bid Withdrawn              15630
# Transfer                   13484
# Claimed                    10000
# Offer Withdrawn             9718
# (Wrap)                      2763
# (Unwrap)                    2520

# %%
typesTransact.reset_index(level=0, inplace=True)
typesTransact = typesTransact.rename(columns={'index':'TransactionType','TypeTransaction':'typeSum'})
typesTransact
# Out:
#    TransactionType  typeSum
# 0          Offered    62822
# 1              Bid    25923
# 2             Sold    18425
# 3    Bid Withdrawn    15630
# 4         Transfer    13484
# 5          Claimed    10000
# 6  Offer Withdrawn     9718
# 7           (Wrap)     2763
# 8         (Unwrap)     2520

# %%
dfi.export(typesTransact, 'transactions_types_df.png')

# %%
# plot it
squarify.plot(sizes=typesTransact["typeSum"], label=typesTransact["TransactionType"], alpha=.8 )
plt.axis('off')
plt.savefig('transaction_type_plot.png')
plt.show()

# %%
ax = sns.boxplot(y="AmountDollar", data=transact_df,  color='lightblue', fliersize=10,  orient='v', linewidth=1 , width=0.3)
#ax = sns.swarmplot(y="AmountDollar", data=transact_df, color="darkblue", orient="v", size=4)

# %%
transact_df.isnull().sum()
# Out:
# idTransaction           0
# idPropietario       71822
# TypeTransaction         0
# idCryptoPunk            0
# Owner               82540
# Reciever           113376
# AmountETH               0
# AmountDollar            0
# Date                    0
# dtype: int64

# %%
transact_df.fillna(0, inplace=True)

# %%
transact_df.isnull().sum()
# Out:
# idTransaction      0
# idPropietario      0
# TypeTransaction    0
# idCryptoPunk       0
# Owner              0
# Reciever           0
# AmountETH          0
# AmountDollar       0
# Date               0
# dtype: int64

# %%
transact_df.duplicated().sum()
# Out:
# 0

# %%
transact_describe_df=transact_df.describe()
transact_describe_df=transact_describe_df[['AmountETH', 'AmountDollar']].describe()
dfi.export(transact_describe_df, 'describe_allTransact_df.png')

# %%
offered_df = transact_df[transact_df.TypeTransaction == 'Offered']
offered_describe_df=offered_df[['AmountETH', 'AmountDollar']].describe()
dfi.export(offered_describe_df, 'describe_offered_df.png')

# %%
bid_df = transact_df[transact_df.TypeTransaction == 'Bid']
bid_describe_df=bid_df[['AmountETH', 'AmountDollar']].describe()
dfi.export(bid_describe_df, 'describe_bid_df.png')

# %%
sold_df = transact_df[transact_df.TypeTransaction == 'Sold']
sold_describe_df = sold_df[['AmountETH', 'AmountDollar']].describe()
dfi.export(sold_describe_df, 'describe_sold_df.png')

# %%
print(transact_df.AmountETH.var())
print(transact_df.AmountDollar.var())
print(bid_df.AmountETH.var())
print(bid_df.AmountDollar.var())
print(sold_df.AmountETH.var())
print(sold_df.AmountDollar.var())
print(offered_df.AmountETH.var())
print(offered_df.AmountDollar.var())
# Out:
# 14045653.666564576
# 9724754489176.455
# 7854.891639467128
# 51909473426.86223
# 4471.32734797033
# 28338114909.072926
# 36041649.489612065
# 24876428077792.324

# %%
ax=sns.boxplot(y=transact_df.AmountDollar)
ax.set_title('Distribución - Todas Transacciones')
plt.savefig('describeAll_plot.png')

# %%
#filteredTransact_df = mergedPunks_df[mergedPunks_df.TypeTransaction.isin(['Bid','Bid Withdrawn','Offered','Sold'])]
partialTransact_df=transact_df[transact_df.TypeTransaction.isin(['Bid','Sold','Offered'])]
partialTransact_df.TypeTransaction.value_counts()
# Out:
# Offered    62822
# Bid        25923
# Sold       18425
# Name: TypeTransaction, dtype: int64

# %%
ax=sns.boxplot(x=partialTransact_df["TypeTransaction"], y=partialTransact_df["AmountDollar"])
ax.set_title('Distribución - Transacciones Bid, Sold y Offered')
plt.savefig('describeTransact_plot.png')

# %%
sns.boxplot(x=partialTransact_df["TypeTransaction"], y=partialTransact_df["AmountETH"])
plt.savefig('describeTransactETH_plot.png')

# %%
transact_df.groupby("TypeTransaction")["AmountETH"].mean()
# Out:
# TypeTransaction
# (Unwrap)             0.000000
# (Wrap)               0.000000
# Bid                 25.177171
# Bid Withdrawn       32.196468
# Claimed              0.000000
# Offer Withdrawn      0.000000
# Offered            151.471986
# Sold                26.572926
# Transfer             0.000000
# Name: AmountETH, dtype: float64

# %%
transact_df.groupby("TypeTransaction")["AmountETH"].median()
# Out:
# TypeTransaction
# (Unwrap)            0.00
# (Wrap)              0.00
# Bid                 6.00
# Bid Withdrawn      14.00
# Claimed             0.00
# Offer Withdrawn     0.00
# Offered            28.99
# Sold               14.65
# Transfer            0.00
# Name: AmountETH, dtype: float64

# %%
transact_df.groupby("TypeTransaction")["AmountDollar"].mean()
# Out:
# TypeTransaction
# (Unwrap)                0.000000
# (Wrap)                  0.000000
# Bid                 60105.511476
# Bid Withdrawn       78574.674157
# Claimed                 0.000000
# Offer Withdrawn         0.000000
# Offered            299837.916059
# Sold                67942.507967
# Transfer                0.000000
# Name: AmountDollar, dtype: float64

# %%
transact_df.groupby("TypeTransaction")["AmountDollar"].median()
# Out:
# TypeTransaction
# (Unwrap)               0.0
# (Wrap)                 0.0
# Bid                 5581.0
# Bid Withdrawn      26818.0
# Claimed                0.0
# Offer Withdrawn        0.0
# Offered            60426.0
# Sold               26702.0
# Transfer               0.0
# Name: AmountDollar, dtype: float64

# %%
transact_df.groupby("TypeTransaction")["AmountDollar"].var()
# Out:
# TypeTransaction
# (Unwrap)           0.000000e+00
# (Wrap)             0.000000e+00
# Bid                5.190947e+10
# Bid Withdrawn      7.285500e+10
# Claimed            0.000000e+00
# Offer Withdrawn    0.000000e+00
# Offered            2.487643e+13
# Sold               2.833811e+10
# Transfer           0.000000e+00
# Name: AmountDollar, dtype: float64

# %%
transact_df.head(1)
# Out:
#    idTransaction idPropietario TypeTransaction  idCryptoPunk     Owner  \
# 0              0      0xe73a1d   Bid Withdrawn             0  0xe73a1d
#
#   Reciever  AmountETH  AmountDollar        Date
# 0        0      321.0     1260000.0  2021-09-04

# %%
sold_df = transact_df[transact_df.TypeTransaction == 'Sold']

# %%
sold_df.Date.value_counts()
# Out:
# 2021-08-23    354
# 2021-07-30    337
# 2020-09-24    327
# 2020-09-28    312
# 2021-08-28    307
#              ...
# 2019-10-31      1
# 2019-04-04      1
# 2019-11-29      1
# 2019-10-23      1
# 2017-10-21      1
# Name: Date, Length: 1150, dtype: int64

# %%
soldDates=pd.DataFrame(sold_df.groupby("Date")["AmountDollar"].median())
soldDates
# Out:
#             AmountDollar
# Date
# 2017-06-23          31.0
# 2017-06-24          53.5
# 2017-06-25          38.0
# 2017-06-26          24.5
# 2017-06-27          43.5
# ...                  ...
# 2021-09-04      395299.0
# 2021-09-05      390640.0
# 2021-09-06      393122.5
# 2021-09-07      394065.5
# 2021-09-08      348364.0
#
# [1150 rows x 1 columns]

# %%
soldDates.reset_index(level=0, inplace=True)
soldDates
# Out:
#             Date  AmountDollar
# 0     2017-06-23          31.0
# 1     2017-06-24          53.5
# 2     2017-06-25          38.0
# 3     2017-06-26          24.5
# 4     2017-06-27          43.5
# ...          ...           ...
# 1145  2021-09-04      395299.0
# 1146  2021-09-05      390640.0
# 1147  2021-09-06      393122.5
# 1148  2021-09-07      394065.5
# 1149  2021-09-08      348364.0
#
# [1150 rows x 2 columns]

# %%
soldDates["Date"] = pd.to_datetime(soldDates["Date"])

date = soldDates["Date"]
value = soldDates["AmountDollar"]

fig, ax = plt.subplots(figsize=(12, 9))
ax.plot(date, value);

# %%
soldDatesETH=pd.DataFrame(sold_df.groupby("Date")["AmountDollar","AmountETH"].median())
soldDatesETH
# Out:
#             AmountDollar  AmountETH
# Date
# 2017-06-23          31.0      0.095
# 2017-06-24          53.5      0.175
# 2017-06-25          38.0      0.140
# 2017-06-26          24.5      0.095
# 2017-06-27          43.5      0.150
# ...                  ...        ...
# 2021-09-04      395299.0    102.000
# 2021-09-05      390640.0    100.000
# 2021-09-06      393122.5    100.000
# 2021-09-07      394065.5    104.500
# 2021-09-08      348364.0    100.000
#
# [1150 rows x 2 columns]

# %%
soldDatesETH.reset_index(level=0, inplace=True)
soldDatesETH.head(1)
# Out:
#          Date  AmountDollar  AmountETH
# 0  2017-06-23          31.0      0.095

# %%
x=soldDatesETH["Date"]
y1=soldDatesETH["AmountDollar"]
y2=soldDatesETH["AmountETH"]

fig, ax1 = plt.subplots(figsize=(18, 10))
ax2 = ax1.twinx()

ax1.plot(x, y1)
ax2.plot(x, y2, color='red');

# %% [markdown]
# #### Ethereum

# %%
# Ethereum Historical Data
# Source: https://www.investing.com/crypto/ethereum/historical-data

ethereum_df=pd.read_csv('ethereumHistoricalData.csv')
ethereum_df
# Out:
#               Date     Price      Open      High       Low     Vol. Change %
# 0     Sep 08, 2021  3,495.10  3,424.35  3,557.67  3,221.60  780.68K    2.10%
# 1     Sep 07, 2021  3,423.12  3,926.84  3,945.79  3,061.30    2.47M  -12.84%
# 2     Sep 06, 2021  3,927.21  3,950.20  3,968.20  3,867.55  764.56K   -0.59%
# 3     Sep 05, 2021  3,950.62  3,885.40  3,981.22  3,834.74  714.16K    1.69%
# 4     Sep 04, 2021  3,884.97  3,938.45  3,968.33  3,844.07  672.53K   -1.30%
# ...            ...       ...       ...       ...       ...      ...      ...
# 1534  Jun 27, 2017    279.00    251.30    279.00    204.11    1.09M   11.02%
# 1535  Jun 26, 2017    251.30    277.00    286.85    214.99    1.36M   -9.28%
# 1536  Jun 25, 2017    277.00    296.89    306.39    253.20  508.55K   -6.70%
# 1537  Jun 24, 2017    296.89    324.37    327.55    291.53  195.47K   -8.47%
# 1538  Jun 23, 2017    324.37    320.94    329.90    316.36  105.60K    1.07%
#
# [1539 rows x 7 columns]

# %%
ethereum_df["Date"] = pd.to_datetime(ethereum_df["Date"])
ethereum_df.head()
# Out:
#         Date     Price      Open      High       Low     Vol. Change %
# 0 2021-09-08  3,495.10  3,424.35  3,557.67  3,221.60  780.68K    2.10%
# 1 2021-09-07  3,423.12  3,926.84  3,945.79  3,061.30    2.47M  -12.84%
# 2 2021-09-06  3,927.21  3,950.20  3,968.20  3,867.55  764.56K   -0.59%
# 3 2021-09-05  3,950.62  3,885.40  3,981.22  3,834.74  714.16K    1.69%
# 4 2021-09-04  3,884.97  3,938.45  3,968.33  3,844.07  672.53K   -1.30%

# %%
ethereum_df[ethereum_df.columns[1:5]] = ethereum_df[ethereum_df.columns[1:5]].replace('[,]', '', regex=True).astype(float)

# %%
ethereum_df.head()
# Out:
#         Date    Price     Open     High      Low     Vol. Change %
# 0 2021-09-08  3495.10  3424.35  3557.67  3221.60  780.68K    2.10%
# 1 2021-09-07  3423.12  3926.84  3945.79  3061.30    2.47M  -12.84%
# 2 2021-09-06  3927.21  3950.20  3968.20  3867.55  764.56K   -0.59%
# 3 2021-09-05  3950.62  3885.40  3981.22  3834.74  714.16K    1.69%
# 4 2021-09-04  3884.97  3938.45  3968.33  3844.07  672.53K   -1.30%

# %%
ethereum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1539 entries, 0 to 1538
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1539 non-null   datetime64[ns]
#  1   Price     1539 non-null   float64
#  2   Open      1539 non-null   float64
#  3   High      1539 non-null   float64
#  4   Low       1539 non-null   float64
#  5   Vol.      1539 non-null   object
#  6   Change %  1539 non-null   object
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 84.3+ KB

# %%
ethereum_df.isnull().sum()
# Out:
# Date        0
# Price       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
dateEth = ethereum_df["Date"]
valueEth = ethereum_df["Price"]

fig, ax = plt.subplots(figsize=(12, 9))
ax.plot(dateEth, valueEth);

# %%
transactions_df['Date'] = pd.to_datetime(transactions_df['Date'])
ethereum_df['Date'] = pd.to_datetime(ethereum_df['Date'])
concatValues_df = pd.merge(transactions_df, ethereum_df, how='inner', left_on='Date', right_on='Date')
concatValues_df
# Out:
#         idTransaction idPropietario TypeTransaction  idCryptoPunk      Owner  \
# 0                   0      0xe73a1d   Bid Withdrawn             0   0xe73a1d
# 1                  41      0xe73a1d   Bid Withdrawn             1   0xe73a1d
# 2                 179     snoopalo…             Bid             6  snoopalo…
# 3                 393     snoopalo…             Bid            28  snoopalo…
# 4                 415     snoopalo…             Bid            35  snoopalo…
# ...               ...           ...             ...           ...        ...
# 161280         154486       trislit             Bid          9623    trislit
# 161281         156122        satman            Sold          9697  _K_A_M_I…
# 161282         159968           NaN         Offered          9919        NaN
# 161283         160490      GoWest23            Sold          9943  antunes_…
# 161284         160491           NaN         Offered          9943        NaN
#
#         Reciever  AmountETH  AmountDollar       Date    Price     Open  \
# 0            NaN     321.00     1260000.0 2021-09-04  3884.97  3938.45
# 1            NaN     198.00      777132.0 2021-09-04  3884.97  3938.45
# 2            NaN       1.00        3923.0 2021-09-04  3884.97  3938.45
# 3            NaN       0.50        1962.0 2021-09-04  3884.97  3938.45
# 4            NaN       0.50        1962.0 2021-09-04  3884.97  3938.45
# ...          ...        ...           ...        ...      ...      ...
# 161280       NaN       0.15          34.0 2018-10-10   226.30   228.28
# 161281    satman       0.60          80.0 2020-04-01   135.66   132.88
# 161282       NaN       0.25          70.0 2018-08-21   280.90   271.90
# 161283  GoWest23       0.50          86.0 2019-08-31   171.62   168.14
# 161284       NaN       0.50          86.0 2019-08-31   171.62   168.14
#
#            High      Low     Vol. Change %
# 0       3968.33  3844.07  672.53K   -1.30%
# 1       3968.33  3844.07  672.53K   -1.30%
# 2       3968.33  3844.07  672.53K   -1.30%
# 3       3968.33  3844.07  672.53K   -1.30%
# 4       3968.33  3844.07  672.53K   -1.30%
# ...         ...      ...      ...      ...
# 161280   231.32   224.74    1.07M   -0.85%
# 161281   136.56   128.93   19.45M    2.10%
# 161282   282.77   270.26    2.97M    3.62%
# 161283   174.43   166.16    7.89M    2.06%
# 161284   174.43   166.16    7.89M    2.06%
#
# [161285 rows x 15 columns]

# %%
soldValues_df = concatValues_df[concatValues_df.TypeTransaction == 'Sold']
soldValues_df.head(3)
# Out:
#     idTransaction idPropietario TypeTransaction  idCryptoPunk     Owner  \
# 6            5849      0x285ce8            Sold           618  0xd7047c
# 12          12395      0x04fd71            Sold          1186  0x081e92
# 17          13666      0xb56b7d            Sold          1316  0xb73440
#
#     Reciever  AmountETH  AmountDollar       Date    Price     Open     High  \
# 6   0x285ce8      97.25      381146.0 2021-09-04  3884.97  3938.45  3968.33
# 12  0x04fd71      98.00      378256.0 2021-09-04  3884.97  3938.45  3968.33
# 17  0xb56b7d     105.00      406925.0 2021-09-04  3884.97  3938.45  3968.33
#
#         Low     Vol. Change %
# 6   3844.07  672.53K   -1.30%
# 12  3844.07  672.53K   -1.30%
# 17  3844.07  672.53K   -1.30%

# %%
soldValuesDates_df=pd.DataFrame(soldValues_df.groupby("Date")["AmountDollar","AmountETH","Price"].median())
soldValuesDates_df
# Out:
#             AmountDollar  AmountETH    Price
# Date
# 2017-06-23          31.0      0.095   324.37
# 2017-06-24          53.5      0.175   296.89
# 2017-06-25          38.0      0.140   277.00
# 2017-06-26          24.5      0.095   251.30
# 2017-06-27          43.5      0.150   279.00
# ...                  ...        ...      ...
# 2021-09-04      395299.0    102.000  3884.97
# 2021-09-05      390640.0    100.000  3950.62
# 2021-09-06      393122.5    100.000  3927.21
# 2021-09-07      394065.5    104.500  3423.12
# 2021-09-08      348364.0    100.000  3495.10
#
# [1150 rows x 3 columns]

# %%
soldValuesDates_df.reset_index(level=0, inplace=True)
soldValuesDates_df
# Out:
#            Date  AmountDollar  AmountETH    Price
# 0    2017-06-23          31.0      0.095   324.37
# 1    2017-06-24          53.5      0.175   296.89
# 2    2017-06-25          38.0      0.140   277.00
# 3    2017-06-26          24.5      0.095   251.30
# 4    2017-06-27          43.5      0.150   279.00
# ...         ...           ...        ...      ...
# 1145 2021-09-04      395299.0    102.000  3884.97
# 1146 2021-09-05      390640.0    100.000  3950.62
# 1147 2021-09-06      393122.5    100.000  3927.21
# 1148 2021-09-07      394065.5    104.500  3423.12
# 1149 2021-09-08      348364.0    100.000  3495.10
#
# [1150 rows x 4 columns]

# %%
x=soldValuesDates_df["Date"]
y1=soldValuesDates_df["AmountDollar"]
y2=soldValuesDates_df["Price"]

fig, ax1 = plt.subplots(figsize=(18, 10))
ax2 = ax1.twinx()


ax1.plot(x, y1)
ax2.plot(x, y2, color='green');

# %%
x=soldValuesDates_df["Date"]
y1=soldValuesDates_df["AmountETH"]
y2=soldValuesDates_df["Price"]

fig, ax1 = plt.subplots(figsize=(18, 10))
ax2 = ax1.twinx()


ax1.plot(x, y1, color='red')
ax2.plot(x, y2, color='green');

# %%
ethereumPrice_df=ethereum_df[['Date','Price']]
ethereumPrice_df=ethereumPrice_df.rename(columns={'Price':'priceETH'})
ethereumPrice_df.head(3)
# Out:
#         Date  priceETH
# 0 2021-09-08   3495.10
# 1 2021-09-07   3423.12
# 2 2021-09-06   3927.21

# %% [markdown]
# ### MERGE CYBERPUNKS AND TRANSACTIONS

# %%
# Merge parameters and transacciones
mergedPunks = pd.merge(left=transactions_df, right=cyberpunks_df, how='left', left_on='idCryptoPunk', right_index=True)

# %%
mergedPunks
# Out:
#         idTransaction idPropietario TypeTransaction  idCryptoPunk     Owner  \
# 0                   0      0xe73a1d   Bid Withdrawn             0  0xe73a1d
# 1                   1      0xe73a1d             Bid             0  0xe73a1d
# 2                   2      0x2e5e22   Bid Withdrawn             0  0x2e5e22
# 3                   3      0x2e5e22             Bid             0  0x2e5e22
# 4                   4      0x2e5e22   Bid Withdrawn             0  0x2e5e22
# ...               ...           ...             ...           ...       ...
# 161280         161329      0xa0a59c             Bid          9999  0xa0a59c
# 161281         161330      0x717403             Bid          9999  0x717403
# 161282         161331      ddaavvee             Bid          9999  ddaavvee
# 161283         161332      0x5b098b             Bid          9999  0x5b098b
# 161284         161333      0x7e2d1c         Claimed          9999       NaN
#
#         Reciever  AmountETH  AmountDollar       Date  rarity_rank   tipus  \
# 0            NaN     321.00     1260000.0 2021-09-04         2023  Female
# 1            NaN     321.00     1140000.0 2021-09-01         2023  Female
# 2            NaN     320.00     1110000.0 2021-09-01         2023  Female
# 3            NaN     320.00     1100000.0 2021-09-01         2023  Female
# 4            NaN     263.00      904481.0 2021-09-01         2023  Female
# ...          ...        ...           ...        ...          ...     ...
# 161280       NaN       0.25          69.0 2017-07-03         9233  Female
# 161281       NaN       0.20          51.0 2017-06-26         9233  Female
# 161282       NaN       0.20          65.0 2017-06-23         9233  Female
# 161283       NaN       0.15          50.0 2017-06-23         9233  Female
# 161284  0x7e2d1c       0.00           0.0 2017-06-23         9233  Female
#
#                 skin                                             traits  \
# 0        Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
# 1        Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
# 2        Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
# 3        Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
# 4        Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
# ...              ...                                                ...
# 161280  Dark-skinned                               Mohawk, Nerd Glasses
# 161281  Dark-skinned                               Mohawk, Nerd Glasses
# 161282  Dark-skinned                               Mohawk, Nerd Glasses
# 161283  Dark-skinned                               Mohawk, Nerd Glasses
# 161284  Dark-skinned                               Mohawk, Nerd Glasses
#
#         traits_count     owner
# 0                  4  0xE08c32
# 1                  4  0xE08c32
# 2                  4  0xE08c32
# 3                  4  0xE08c32
# 4                  4  0xE08c32
# ...              ...       ...
# 161280             2  0x0A383e
# 161281             2  0x0A383e
# 161282             2  0x0A383e
# 161283             2  0x0A383e
# 161284             2  0x0A383e
#
# [161285 rows x 15 columns]

# %%
mergedPunks.to_csv('mergedPunks.csv')

# %%
mergedPunks['Date'] = pd.to_datetime(mergedPunks['Date'])
ethereumPrice_df['Date'] = pd.to_datetime(ethereumPrice_df['Date'])
mergedPunks_df = pd.merge(mergedPunks, ethereumPrice_df, how='inner', left_on='Date', right_on='Date')
mergedPunks_df.head()
# Out:
#    idTransaction idPropietario TypeTransaction  idCryptoPunk      Owner  \
# 0              0      0xe73a1d   Bid Withdrawn             0   0xe73a1d
# 1             41      0xe73a1d   Bid Withdrawn             1   0xe73a1d
# 2            179     snoopalo…             Bid             6  snoopalo…
# 3            393     snoopalo…             Bid            28  snoopalo…
# 4            415     snoopalo…             Bid            35  snoopalo…
#
#   Reciever  AmountETH  AmountDollar       Date  rarity_rank   tipus  \
# 0      NaN      321.0     1260000.0 2021-09-04         2023  Female
# 1      NaN      198.0      777132.0 2021-09-04         4352    Male
# 2      NaN        1.0        3923.0 2021-09-04         7425    Male
# 3      NaN        0.5        1962.0 2021-09-04         8763    Male
# 4      NaN        0.5        1962.0 2021-09-04         3351    Male
#
#            skin                                             traits  \
# 0   Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
# 1  Dark-skinned                                      Mohawk, Smile
# 2   Mid-skinned                                             Do-rag
# 3  Dark-skinned                             Big Shades, Crazy Hair
# 4  Dark-skinned  Cigarette, Earring, Horned Rim Glasses, Normal...
#
#    traits_count     owner  priceETH
# 0             4  0xE08c32   3884.97
# 1             2  0xB88F61   3884.97
# 2             1  0xC352B5   3884.97
# 3             2  0xC352B5   3884.97
# 4             5  0xC352B5   3884.97

# %%
mergedPunks_df.to_csv('TotalPunks.csv')

# %%
# Change owner columns names to avoid confusion
mergedPunks_df=mergedPunks_df.rename(columns={'Owner':'TransactionOwner','owner':'CurrentOwner'})
mergedPunks_df.head(1)
# Out:
#    idTransaction idPropietario TypeTransaction  idCryptoPunk TransactionOwner  \
# 0              0      0xe73a1d   Bid Withdrawn             0         0xe73a1d
#
#   Reciever  AmountETH  AmountDollar       Date  rarity_rank   tipus  \
# 0      NaN      321.0     1260000.0 2021-09-04         2023  Female
#
#           skin                                             traits  \
# 0  Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
#
#    traits_count CurrentOwner  priceETH
# 0             4     0xE08c32   3884.97

# %%
pd.DataFrame(mergedPunks_df.groupby(["tipus","TypeTransaction"])["AmountDollar"].median())
# Out:
#                         AmountDollar
# tipus  TypeTransaction
# Alien  Bid                     383.5
#        Bid Withdrawn          4052.0
#        Claimed                   0.0
#        Offer Withdrawn           0.0
#        Offered              157724.5
#        Sold                   2650.0
#        Transfer                  0.0
# Ape    (Unwrap)                  0.0
#        (Wrap)                    0.0
#        Bid                     587.0
#        Bid Withdrawn          3680.0
#        Claimed                   0.0
#        Offer Withdrawn           0.0
#        Offered              117512.5
#        Sold                   2212.0
#        Transfer                  0.0
# Female (Unwrap)                  0.0
#        (Wrap)                    0.0
#        Bid                    2648.0
#        Bid Withdrawn         13294.0
#        Claimed                   0.0
#        Offer Withdrawn           0.0
#        Offered               65486.0
#        Sold                  35255.0
#        Transfer                  0.0
# Male   (Unwrap)                  0.0
#        (Wrap)                    0.0
#        Bid                   16895.5
#        Bid Withdrawn         32512.0
#        Claimed                   0.0
#        Offer Withdrawn           0.0
#        Offered               57802.0
#        Sold                  18322.0
#        Transfer                  0.0
# Zombie (Unwrap)                  0.0
#        (Wrap)                    0.0
#        Bid                     420.0
#        Bid Withdrawn          1964.0
#        Claimed                   0.0
#        Offer Withdrawn           0.0
#        Offered              221074.5
#        Sold                  17948.0
#        Transfer                  0.0

# %%
pd.set_option('display.max_rows', 70)
pd.DataFrame(mergedPunks_df.groupby(["skin","TypeTransaction"])["AmountDollar"].median())
# Out:
#                                 AmountDollar
# skin           TypeTransaction
# Albino-skinned (Unwrap)                  0.0
#                (Wrap)                    0.0
#                Bid                   18246.0
#                Bid Withdrawn         36173.0
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered               80916.0
#                Sold                  35021.0
#                Transfer                  0.0
# Alien-skinned  Bid                     383.5
#                Bid Withdrawn          4052.0
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered              157724.5
#                Sold                   2650.0
#                Transfer                  0.0
# Ape-skinned    (Unwrap)                  0.0
#                (Wrap)                    0.0
#                Bid                     587.0
#                Bid Withdrawn          3680.0
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered              117512.5
#                Sold                   2212.0
#                Transfer                  0.0
# Dark-skinned   (Unwrap)                  0.0
#                (Wrap)                    0.0
#                Bid                    5937.0
#                Bid Withdrawn         25262.0
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered               56602.0
#                Sold                  22206.0
#                Transfer                  0.0
# Light-skinned  (Unwrap)                  0.0
#                (Wrap)                    0.0
#                Bid                    6241.0
#                Bid Withdrawn         27588.0
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered               61565.0
#                Sold                  29329.0
#                Transfer                  0.0
# Mid-skinned    (Unwrap)                  0.0
#                (Wrap)                    0.0
#                Bid                    6075.0
#                Bid Withdrawn         27798.5
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered               57015.0
#                Sold                  20661.0
#                Transfer                  0.0
# Zombie-skinned (Unwrap)                  0.0
#                (Wrap)                    0.0
#                Bid                     420.0
#                Bid Withdrawn          1964.0
#                Claimed                   0.0
#                Offer Withdrawn           0.0
#                Offered              221074.5
#                Sold                  17948.0
#                Transfer                  0.0

# %%
pd.DataFrame(mergedPunks_df.groupby(["traits_count","TypeTransaction"])["AmountDollar"].median())
# Out:
#                               AmountDollar
# traits_count TypeTransaction
# 0            Bid                     471.0
#              Bid Withdrawn          2213.0
#              Claimed                   0.0
#              Offer Withdrawn           0.0
#              Offered                6760.0
# ...                                    ...
# 9            Claimed                   0.0
#              Offer Withdrawn           0.0
#              Offered                2797.0
#              Sold                    629.0
#              Transfer                  0.0
#
# [77 rows x 1 columns]

# %%
mergedPunks_df.describe()
# Out:
#        idTransaction   idCryptoPunk       AmountETH  AmountDollar  \
# count  161285.000000  161285.000000   161285.000000  1.612850e+05
# mean    80669.917872    5317.588269       69.202206  1.418266e+05
# std     46574.389486    2779.883907     3747.753149  3.118454e+06
# min         0.000000       0.000000        0.000000  0.000000e+00
# 25%     40335.000000    2979.000000        0.020000  1.100000e+01
# 50%     80671.000000    5396.000000        6.660000  4.376000e+03
# 75%    121006.000000    7705.000000       34.000000  7.453800e+04
# max    161333.000000    9999.000000  1000000.000000  5.812800e+08
#
#          rarity_rank   traits_count       priceETH
# count  161285.000000  161285.000000  161285.000000
# mean     4730.603683       2.845311    1615.187597
# std      2927.894793       0.944229    1153.564242
# min         1.000000       0.000000      83.810000
# 25%      2220.000000       2.000000     344.030000
# 50%      4640.000000       3.000000    1777.280000
# 75%      7238.000000       3.000000    2532.190000
# max     10000.000000       9.000000    4167.780000

# %%
# Filter relevant columns to show statistics data
punksStat_df = mergedPunks_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].copy()
punksStat_df.describe()
# Out:
#             AmountETH  AmountDollar    rarity_rank   traits_count
# count   161285.000000  1.612850e+05  161285.000000  161285.000000
# mean        69.202206  1.418266e+05    4730.603683       2.845311
# std       3747.753149  3.118454e+06    2927.894793       0.944229
# min          0.000000  0.000000e+00       1.000000       0.000000
# 25%          0.020000  1.100000e+01    2220.000000       2.000000
# 50%          6.660000  4.376000e+03    4640.000000       3.000000
# 75%         34.000000  7.453800e+04    7238.000000       3.000000
# max    1000000.000000  5.812800e+08   10000.000000       9.000000

# %%
# Filter only 'Bid','Bid Withdrawn','Offered','Sold' transactions
pd.set_option('display.float_format', lambda x: '%.2f' % x) # set to decimals and no scientific notation
#pd.reset_option('display.float_format') # command to resert set_option
filteredTransact_df = mergedPunks_df[mergedPunks_df.TypeTransaction.isin(['Bid','Bid Withdrawn','Offered','Sold'])]

#Groupby mean
transact_groupbyTipus_df=pd.DataFrame(filteredTransact_df.groupby(["tipus","TypeTransaction"])["AmountDollar"].mean())
dfi.export(transact_groupbyTipus_df, 'transact_groupbyTipus_df.png')

# %%
pd.DataFrame(filteredTransact_df.groupby(["skin","TypeTransaction"])["AmountDollar"].mean())
# Out:
#                                 AmountDollar
# skin           TypeTransaction
# Albino-skinned Bid                  53748.41
#                Bid Withdrawn        68847.95
#                Offered             319890.26
#                Sold                 70285.83
# Alien-skinned  Bid                 278329.90
#                Bid Withdrawn       521079.68
#                Offered           34736008.14
#                Sold               1593972.30
# Ape-skinned    Bid                 354991.63
#                Bid Withdrawn       662034.23
#                Offered            6044690.43
#                Sold                431928.33
# Dark-skinned   Bid                  46070.17
#                Bid Withdrawn        56057.21
#                Offered             267607.60
#                Sold                 63781.47
# Light-skinned  Bid                  53102.53
#                Bid Withdrawn        66716.59
#                Offered             256654.99
#                Sold                 67551.04
# Mid-skinned    Bid                  48204.77
#                Bid Withdrawn        62002.52
#                Offered             250285.78
#                Sold                 60076.64
# Zombie-skinned Bid                 190415.29
#                Bid Withdrawn       272385.55
#                Offered            1206318.95
#                Sold                437547.65

# %%
pd.DataFrame(filteredTransact_df.groupby(["traits_count","TypeTransaction"])["AmountDollar"].mean())
# Out:
#                               AmountDollar
# traits_count TypeTransaction
# 0            Bid                  40444.92
#              Bid Withdrawn        72386.26
#              Offered             707500.37
#              Sold                110708.09
# 1            Bid                  95776.07
#              Bid Withdrawn       135652.53
#              Offered            1302831.07
#              Sold                138959.23
# 2            Bid                  65800.93
#              Bid Withdrawn        85058.29
#              Offered             234023.02
#              Sold                 71430.24
# 3            Bid                  55971.92
#              Bid Withdrawn        74220.03
#              Offered             314681.27
#              Sold                 62240.75
# 4            Bid                  48981.91
#              Bid Withdrawn        65464.64
#              Offered             255708.82
#              Sold                 63950.54
# 5            Bid                  55143.31
#              Bid Withdrawn        63508.02
#              Offered             290925.61
#              Sold                 84485.58
# 6            Bid                  49803.90
#              Bid Withdrawn        61221.30
#              Offered             364150.77
#              Sold                124128.12
# 7            Bid                 107657.02
#              Bid Withdrawn       104385.84
#              Offered            1785395.18
#              Sold                127754.67
# 9            Bid                  29749.31
#              Bid Withdrawn        55180.50
#              Offered            1060935.06
#              Sold                   537.00

# %%
mergedPunks_df.head(1)
# Out:
#    idTransaction idPropietario TypeTransaction  idCryptoPunk TransactionOwner  \
# 0              0      0xe73a1d   Bid Withdrawn             0         0xe73a1d
#
#   Reciever  AmountETH  AmountDollar       Date  rarity_rank   tipus  \
# 0      NaN     321.00    1260000.00 2021-09-04         2023  Female
#
#           skin                                             traits  \
# 0  Mid-skinned  Blonde Bob, Earring, Green Eye Shadow, Hidden ...
#
#    traits_count CurrentOwner  priceETH
# 0             4     0xE08c32   3884.97

# %%
mergedPunks_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count  161285.00     161285.00    161285.00     161285.00
# mean       69.20     141826.55      4730.60          2.85
# std      3747.75    3118453.86      2927.89          0.94
# min         0.00          0.00         1.00          0.00
# 25%         0.02         11.00      2220.00          2.00
# 50%         6.66       4376.00      4640.00          3.00
# 75%        34.00      74538.00      7238.00          3.00
# max   1000000.00  581280000.00     10000.00          9.00

# %%
mergedPunks_df.tipus.value_counts()
# Out:
# Male      100071
# Female     57785
# Zombie      2225
# Ape          783
# Alien        421
# Name: tipus, dtype: int64

# %%
alien_df=mergedPunks_df[mergedPunks_df.tipus=='Alien']
alien_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count     421.00        421.00       421.00        421.00
# mean     1038.73    2649607.53        13.97          2.06
# std      7358.91   19587844.14         2.73          0.75
# min         0.00          0.00        10.00          1.00
# 25%         0.25        135.00        12.00          1.00
# 50%         2.00       1646.00        14.00          2.00
# 75%        51.00      20143.00        17.00          3.00
# max    125000.00  305230000.00        18.00          3.00

# %%
alienAmounts_df=pd.DataFrame(alien_df.groupby("Date")["AmountDollar","AmountETH"].mean())
alienAmounts_df.reset_index(level=0, inplace=True)
alienAmounts_df.head(1)
# Out:
#         Date  AmountDollar  AmountETH
# 0 2017-06-23      25396.20      77.70

# %%
alien_df.head()
# Out:
#       idTransaction idPropietario  TypeTransaction  idCryptoPunk  \
# 166          122490      0xe16ec2              Bid          7804
# 646          122491           NaN  Offer Withdrawn          7804
# 2499         122515      0xffe678              Bid          7804
# 4901           6132           jmg              Bid           635
# 4902           6133      natealex              Bid           635
#
#      TransactionOwner Reciever  AmountETH  AmountDollar       Date  \
# 166          0xe16ec2      NaN       0.01          9.00 2021-09-04
# 646               NaN      NaN       0.00          0.00 2021-09-01
# 2499         0xffe678      NaN       0.80       1722.00 2021-04-11
# 4901              jmg      NaN      30.00       4088.00 2020-01-09
# 4902         natealex      NaN      29.00       4016.00 2020-01-09
#
#       rarity_rank  tipus           skin                           traits  \
# 166            12  Alien  Alien-skinned  Cap Forward, Pipe, Small Shades
# 646            12  Alien  Alien-skinned  Cap Forward, Pipe, Small Shades
# 2499           12  Alien  Alien-skinned  Cap Forward, Pipe, Small Shades
# 4901           18  Alien  Alien-skinned          Bandana, Regular Shades
# 4902           18  Alien  Alien-skinned          Bandana, Regular Shades
#
#       traits_count CurrentOwner  priceETH
# 166              3     0xf4b4A5   3884.97
# 646              3     0xf4b4A5   3832.73
# 2499             3     0xf4b4A5   2151.42
# 4901             2     0x897aEA    137.92
# 4902             2     0x897aEA    137.92

# %%
x=alienAmounts_df["Date"]
y1=alienAmounts_df["AmountDollar"]
y2=alienAmounts_df["AmountETH"]

fig, ax1 = plt.subplots(figsize=(18, 10))
ax2 = ax1.twinx()

ax1.plot(x, y1)
ax2.plot(x, y2, color='red');

# %%
ape_df=mergedPunks_df[mergedPunks_df.tipus=='Ape']
ape_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count     783.00        783.00       783.00        783.00
# mean      560.86    1344085.60        40.17          1.73
# std      4172.15   10715902.47         7.09          0.67
# min         0.00          0.00        30.00          1.00
# 25%         0.23        200.00        34.00          1.00
# 50%         5.00       1527.00        39.00          2.00
# 75%       150.00      71429.00        46.00          2.00
# max    100000.00  244180000.00        53.00          3.00

# %%
female_df=mergedPunks_df[mergedPunks_df.tipus=='Female']
female_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   57785.00      57785.00     57785.00      57785.00
# mean       83.30     121166.84      4020.88          2.89
# std      6010.00    2753532.07      3265.24          1.03
# min         0.00          0.00         2.00          0.00
# 25%         0.05         13.00      1293.00          2.00
# 50%         8.00       5330.00      2764.00          3.00
# 75%        35.00      77711.00      7874.00          3.00
# max   1000000.00  537340000.00      9999.00          9.00

# %%
femaleAmounts_df=pd.DataFrame(female_df.groupby("Date")["AmountDollar","AmountETH"].mean())
femaleAmounts_df.reset_index(level=0, inplace=True)
femaleAmounts_df.head(1)
# Out:
#         Date  AmountDollar  AmountETH
# 0 2017-06-23          0.90       0.00

# %%
x=femaleAmounts_df["Date"]
y1=femaleAmounts_df["AmountDollar"]
y2=femaleAmounts_df["AmountETH"]

fig, ax1 = plt.subplots(figsize=(18, 10))
ax2 = ax1.twinx()

ax1.plot(x, y1)
ax2.plot(x, y2, color='red');

# %%
male_df=mergedPunks_df[mergedPunks_df.tipus=='Male']
male_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count  100071.00     100071.00    100071.00     100071.00
# mean       50.95     128008.00      5290.82          2.84
# std      1185.52    2950746.92      2528.51          0.89
# min         0.00          0.00         1.00          0.00
# 25%         0.01          0.01      3463.00          2.00
# 50%         6.00       4457.00      5239.00          3.00
# 75%        32.35      73220.50      7283.00          3.00
# max    215000.00  581280000.00     10000.00          7.00

# %%
zombie_df=mergedPunks_df[mergedPunks_df.tipus=='Zombie']
zombie_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count    2225.00       2225.00      2225.00       2225.00
# mean      167.62     402282.03       509.71          2.45
# std       483.61    1360008.25        71.89          0.78
# min         0.00          0.00        54.00          1.00
# 25%         0.05         14.00       495.00          2.00
# 50%         2.49        699.00       517.00          2.00
# 75%        80.00      65452.00       542.00          3.00
# max      8890.00   29110000.00       566.00          5.00

# %%
mergedPunks_df.skin.value_counts()
# Out:
# Dark-skinned      48444
# Mid-skinned       46430
# Light-skinned     46255
# Albino-skinned    16727
# Zombie-skinned     2225
# Ape-skinned         783
# Alien-skinned       421
# Name: skin, dtype: int64

# %%
albinoSkin_df=mergedPunks_df[mergedPunks_df.skin=='Albino-skinned']
albinoSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   16727.00      16727.00     16727.00      16727.00
# mean       54.40     149647.89      4997.87          2.68
# std       631.96    2011766.39      2835.24          0.95
# min         0.00          0.00         2.00          0.00
# 25%         0.11         44.00      2688.00          2.00
# 50%        16.00      28096.00      4888.00          3.00
# 75%        40.00      95118.50      7463.00          3.00
# max     60000.00  190360000.00      9994.00          7.00

# %%
alienSkin_df=mergedPunks_df[mergedPunks_df.skin=='Alien-skinned']
alienSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count     421.00        421.00       421.00        421.00
# mean     1038.73    2649607.53        13.97          2.06
# std      7358.91   19587844.14         2.73          0.75
# min         0.00          0.00        10.00          1.00
# 25%         0.25        135.00        12.00          1.00
# 50%         2.00       1646.00        14.00          2.00
# 75%        51.00      20143.00        17.00          3.00
# max    125000.00  305230000.00        18.00          3.00

# %%
apeSkin_df=mergedPunks_df[mergedPunks_df.skin=='Ape-skinned']
apeSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count     783.00        783.00       783.00        783.00
# mean      560.86    1344085.60        40.17          1.73
# std      4172.15   10715902.47         7.09          0.67
# min         0.00          0.00        30.00          1.00
# 25%         0.23        200.00        34.00          1.00
# 50%         5.00       1527.00        39.00          2.00
# 75%       150.00      71429.00        46.00          2.00
# max    100000.00  244180000.00        53.00          3.00

# %%
darkSkin_df=mergedPunks_df[mergedPunks_df.skin=='Dark-skinned']
darkSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   48444.00      48444.00     48444.00      48444.00
# mean       96.18     128542.59      4854.31          2.86
# std      6579.74    3258593.92      2908.03          0.97
# min         0.00          0.00         4.00          0.00
# 25%         0.00          0.00      2429.00          2.00
# 50%         5.50       2941.00      4613.00          3.00
# 75%        31.33      69986.75      7413.00          3.00
# max   1000000.00  581280000.00      9996.00          9.00

# %%
lightSkin_df=mergedPunks_df[mergedPunks_df.skin=='Light-skinned']
lightSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   46255.00      46255.00     46255.00      46255.00
# mean       46.27     121164.30      4773.68          2.88
# std       837.58    2529531.04      2857.30          0.90
# min         0.00          0.00         6.00          0.00
# 25%         0.05         13.00      2315.00          2.00
# 50%         7.50       5676.00      4778.00          3.00
# 75%        35.00      77101.50      7124.00          3.00
# max    130000.00  489530000.00      9998.00          7.00

# %%
midSkin_df=mergedPunks_df[mergedPunks_df.skin=='Mid-skinned']
midSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   46430.00      46430.00     46430.00      46430.00
# mean       47.43     117957.83      4786.47          2.90
# std      1403.09    3048083.47      2907.41          0.94
# min         0.00          0.00         1.00          0.00
# 25%         0.00          0.00      2310.00          2.00
# 50%         5.50       2844.00      4792.50          3.00
# 75%        31.50      70597.50      7249.00          3.00
# max    250000.00  537340000.00     10000.00          7.00

# %%
zombieSkin_df=mergedPunks_df[mergedPunks_df.skin=='Zombie-skinned']
zombieSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count    2225.00       2225.00      2225.00       2225.00
# mean      167.62     402282.03       509.71          2.45
# std       483.61    1360008.25        71.89          0.78
# min         0.00          0.00        54.00          1.00
# 25%         0.05         14.00       495.00          2.00
# 50%         2.49        699.00       517.00          2.00
# 75%        80.00      65452.00       542.00          3.00
# max      8890.00   29110000.00       566.00          5.00

# %%
mergedPunks_df.traits_count.value_counts()
# Out:
# 3    69683
# 2    57072
# 4    21128
# 5     7207
# 1     4035
# 6     1161
# 7      532
# 0      418
# 9       49
# Name: traits_count, dtype: int64

# %%
zombieSkin_df=mergedPunks_df[mergedPunks_df.skin=='Zombie-skinned']
zombieSkin_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count    2225.00       2225.00      2225.00       2225.00
# mean      167.62     402282.03       509.71          2.45
# std       483.61    1360008.25        71.89          0.78
# min         0.00          0.00        54.00          1.00
# 25%         0.05         14.00       495.00          2.00
# 50%         2.49        699.00       517.00          2.00
# 75%        80.00      65452.00       542.00          3.00
# max      8890.00   29110000.00       566.00          5.00

# %%
cyberpunks_df.traits_count.value_counts()
# Out:
# 3    4280
# 2    3535
# 4    1371
# 5     404
# 1     333
# 6      57
# 7      11
# 0       8
# 9       1
# Name: traits_count, dtype: int64

# %%
traitCount0_df=mergedPunks_df[mergedPunks_df.traits_count==0]
traitCount0_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count     418.00        418.00       418.00        418.00
# mean       87.30     145405.33         5.20          0.00
# std       438.78     974642.01         2.24          0.00
# min         0.00          0.00         2.00          0.00
# 25%         0.50        137.75         4.00          0.00
# 50%         7.00       1492.50         5.00          0.00
# 75%        33.00      21684.25         7.00          0.00
# max      6000.00   12230000.00         9.00          0.00

# %%
traitCount1_df=mergedPunks_df[mergedPunks_df.traits_count==1]
traitCount1_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count    4035.00       4035.00      4035.00       4035.00
# mean      162.19     439944.28      3349.00          1.00
# std      1657.52    5032909.09      2597.08          0.00
# min         0.00          0.00        14.00          1.00
# 25%         0.10         53.00       538.00          1.00
# 50%         5.00       1962.00      4212.00          1.00
# 75%        45.00      81310.00      4522.00          1.00
# max     42070.00  135430000.00      8117.00          1.00

# %%
traitCount2_df=mergedPunks_df[mergedPunks_df.traits_count==2]
traitCount2_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   57072.00      57072.00     57072.00      57072.00
# mean       81.45     118544.88      5000.23          2.00
# std      5951.90    1601256.29      3081.82          0.00
# min         0.00          0.00        10.00          2.00
# 25%         0.00          0.00      2349.00          2.00
# 50%         7.50       5599.00      4891.00          2.00
# 75%        33.50      74179.50      7807.00          2.00
# max   1000000.00  217770000.00     10000.00          2.00

# %%
traitCount3_df=mergedPunks_df[mergedPunks_df.traits_count==3]
traitCount3_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   69683.00      69683.00     69683.00      69683.00
# mean       60.36     147181.17      4976.40          3.00
# std      1758.54    4237323.49      2892.80          0.00
# min         0.00          0.00        11.00          3.00
# 25%         0.01          0.01      2359.00          3.00
# 50%         5.80       3406.00      5193.00          3.00
# 75%        31.00      69478.00      7380.50          3.00
# max    250000.00  581280000.00      9987.00          3.00

# %%
traitCount4_df=mergedPunks_df[mergedPunks_df.traits_count==4]
traitCount4_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count   21128.00      21128.00     21128.00      21128.00
# mean       48.87     120542.69      4352.60          4.00
# std       730.63    1224024.94      2610.90          0.00
# min         0.00          0.00        64.00          4.00
# 25%         0.05         14.00      2092.00          4.00
# 50%         7.76       5153.00      4249.00          4.00
# 75%        35.00      77515.50      6295.00          4.00
# max     88890.00  137430000.00      9958.00          4.00

# %%
traitCount5_df=mergedPunks_df[mergedPunks_df.traits_count==5]
traitCount5_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count    7207.00       7207.00      7207.00       7207.00
# mean       54.53     138329.98      3086.09          5.00
# std       512.66     906839.52      1651.35          0.00
# min         0.00          0.00       111.00          5.00
# 25%         0.10         38.50      1974.00          5.00
# 50%        12.00      10141.00      3270.00          5.00
# 75%        55.00     128814.00      3500.00          5.00
# max     42070.00   68930000.00      9579.00          5.00

# %%
traitCount6_df=mergedPunks_df[mergedPunks_df.traits_count==6]
traitCount6_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count    1161.00       1161.00      1161.00       1161.00
# mean       55.21     137949.04      2346.79          6.00
# std       142.37     398454.77      1239.49          0.00
# min         0.00          0.00        20.00          6.00
# 25%         0.28         74.00      1219.00          6.00
# 50%         8.50       7239.00      3265.00          6.00
# 75%        65.00     132640.00      3289.00          6.00
# max      3330.00    9730000.00      3348.00          6.00

# %%
traitCount7_df=mergedPunks_df[mergedPunks_df.traits_count==7]
traitCount7_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count     532.00        532.00       532.00        532.00
# mean      223.09     552869.05       728.42          7.00
# std      2617.88    7502206.45      1141.88          0.00
# min         0.00          0.00         1.00          7.00
# 25%         0.55        144.00        22.00          7.00
# 50%        16.05       8735.00        29.00          7.00
# 75%        90.00     131613.50      1482.00          7.00
# max     60000.00  171870000.00      3310.00          7.00

# %%
traitCount9_df=mergedPunks_df[mergedPunks_df.traits_count==9]
traitCount9_df[['AmountETH', 'AmountDollar', 'rarity_rank', 'traits_count']].describe()
# Out:
#        AmountETH  AmountDollar  rarity_rank  traits_count
# count      49.00         49.00        49.00         49.00
# mean      155.82     385036.04        26.00          9.00
# std       857.13    2328490.99         0.00          0.00
# min         0.00          0.00        26.00          9.00
# 25%         0.80        202.00        26.00          9.00
# 50%         4.40        758.00        26.00          9.00
# 75%        10.00       2919.00        26.00          9.00
# max      5950.00   16260000.00        26.00          9.00

# %%
mergedPunks_sold_df=mergedPunks_df[mergedPunks_df.TypeTransaction=='Sold']
mergedPunks_sold_df.head(2)
# Out:
#     idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 6            5849      0x285ce8            Sold           618
# 12          12395      0x04fd71            Sold          1186
#
#    TransactionOwner  Reciever  AmountETH  AmountDollar       Date  \
# 6          0xd7047c  0x285ce8      97.25     381146.00 2021-09-04
# 12         0x081e92  0x04fd71      98.00     378256.00 2021-09-04
#
#     rarity_rank   tipus          skin  \
# 6          8420  Female  Dark-skinned
# 12         5442  Female   Mid-skinned
#
#                                                traits  traits_count  \
# 6                         Clown Eyes Green, Wild Hair             2
# 12  Bandana, Black Lipstick, Earring, Purple Eye S...             4
#
#    CurrentOwner  priceETH
# 6      0xf75fcD   3884.97
# 12     0x86B896   3884.97

# %%
pd.set_option('display.max_rows', 75)
sold_groupbyTypeSkin_df = pd.DataFrame(mergedPunks_sold_df.groupby(["tipus","skin","traits_count"])["AmountDollar"].mean())
dfi.export(sold_groupbyTypeSkin_df, 'sold_groupbyTypeSkin_df.png')
sold_groupbyTypeSkin_df
# Out:
#                                     AmountDollar
# tipus  skin           traits_count
# Alien  Alien-skinned  1               1669557.80
#                       2                  2650.00
#                       3               2528878.00
# Ape    Ape-skinned    1                202072.53
#                       2                701120.38
#                       3                  2310.50
# Female Albino-skinned 0                535428.50
#                       1                116897.31
#                       2                 69253.22
#                       3                 65106.41
#                       4                 72885.87
#                       5                133088.51
#                       6                    94.00
#                       7                   415.00
#        Dark-skinned   1                 79187.88
#                       2                 78407.81
#                       3                 63663.95
#                       4                 69780.92
#                       5                 73237.00
#                       6                127509.56
#                       7                 32575.80
#                       9                   537.00
#        Light-skinned  0                   157.00
#                       1                 58547.63
#                       2                 79885.17
#                       3                 70079.57
#                       4                 76322.48
#                       5                 96128.99
#                       6                116408.45
#        Mid-skinned    0                   102.00
#                       1                129750.46
#                       2                 67058.49
#                       3                 63774.43
#                       4                 69621.80
#                       5                 64032.78
#                       6                 81150.00
#                       7                 53782.83
# Male   Albino-skinned 0                 47543.00
#                       1                 86448.07
#                       2                 65841.57
#                       3                 68127.73
#                       4                 73982.72
#                       5                 50484.84
#        Dark-skinned   0                   404.00
#                       1                 54291.78
#                       2                 62291.42
#                       3                 57928.92
#                       4                 56067.13
#                       5                 56167.06
#                       6                156069.67
#                       7                470553.50
#        Light-skinned  0                   304.00
#                       1                 86255.29
#                       2                 67738.37
#                       3                 56211.84
#                       4                 64149.61
#                       5                138032.11
#                       6                476136.50
#                       7                    13.00
#        Mid-skinned    0                  1668.00
#                       1                 61220.81
#                       2                 60682.49
#                       3                 54009.30
#                       4                 54606.26
#                       5                 80659.65
#                       6                 30905.22
#                       7                 17506.38
# Zombie Zombie-skinned 1                581610.60
#                       2                470399.53
#                       3                407260.52
#                       4                202275.57

# %%
sold_perPunk_df=pd.DataFrame(mergedPunks_sold_df.groupby("idCryptoPunk")["TypeTransaction"].count())
#sold_perPunk_df.reset_index(level=0, inplace=True)
#sold_perPunk_df = sold_perPunk_df.rename(columns={'index':'traits_total'})
sold_perPunk_df
# Out:
#               TypeTransaction
# idCryptoPunk
# 0                           3
# 1                           3
# 14                          3
# 33                          1
# 53                          3
# ...                       ...
# 9982                        1
# 9989                        1
# 9990                        2
# 9997                        2
# 9998                        3
#
# [6343 rows x 1 columns]

# %%
sold_perPunk_df.reset_index(level=0, inplace=True)
sold_perPunk_df
# Out:
#       idCryptoPunk  TypeTransaction
# 0                0                3
# 1                1                3
# 2               14                3
# 3               33                1
# 4               53                3
# ...            ...              ...
# 6338          9982                1
# 6339          9989                1
# 6340          9990                2
# 6341          9997                2
# 6342          9998                3
#
# [6343 rows x 2 columns]

# %%
sold_perPunk_df = sold_perPunk_df.rename(columns={'TypeTransaction':'Sold_count'})
sold_perPunk_df.head(1)
# Out:
#    idCryptoPunk  Sold_count
# 0             0           3

# %%
Punks_soldCount_df = pd.merge(mergedPunks_sold_df, sold_perPunk_df, how='inner', left_on='idCryptoPunk', right_on='idCryptoPunk')
Punks_soldCount_df.head()
# Out:
#    idTransaction idPropietario TypeTransaction  idCryptoPunk TransactionOwner  \
# 0           5849      0x285ce8            Sold           618         0xd7047c
# 1           5868      0x4c02b8            Sold           618         0x55e149
# 2           5871      0x55e149            Sold           618         0xf75fcd
# 3           5860      0x1919db            Sold           618         0x4c02b8
# 4           5852      0xd7047c            Sold           618         0x1919db
#
#    Reciever  AmountETH  AmountDollar       Date  rarity_rank   tipus  \
# 0  0x285ce8      97.25     381146.00 2021-09-04         8420  Female
# 1  0x4c02b8     133.99     434962.00 2021-08-29         8420  Female
# 2  0x55e149     120.00     389548.00 2021-08-29         8420  Female
# 3  0x1919db     100.00     338384.00 2021-08-31         8420  Female
# 4  0xd7047c      93.25     370183.00 2021-09-03         8420  Female
#
#            skin                       traits  traits_count CurrentOwner  \
# 0  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 1  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 2  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 3  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 4  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
#
#    priceETH  Sold_count
# 0   3884.97           6
# 1   3222.16           6
# 2   3222.16           6
# 3   3430.74           6
# 4   3936.29           6

# %%
Punks_soldCount_df.to_csv('Punks_soldCount_df.csv')

# %%
Punks_soldCount_df.Sold_count.value_counts()
# Out:
# 2     2926
# 3     2883
# 4     2656
# 5     2145
# 1     2076
# 6     1680
# 7     1218
# 8      936
# 9      522
# 10     500
# 11     308
# 12     228
# 13     143
# 15      60
# 14      56
# 17      51
# 21      21
# 16      16
# Name: Sold_count, dtype: int64

# %%
Punks_soldCount_df[Punks_soldCount_df.Sold_count==21].head()
# Out:
#       idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 3643         142789      0x231d68            Sold          8970
# 3644         142855      Carlini8            Sold          8970
# 3645         142791      0xcacdf5            Sold          8970
# 3646         142793      0x62bdc6            Sold          8970
# 3647         142798        Cyborg            Sold          8970
#
#      TransactionOwner  Reciever  AmountETH  AmountDollar       Date  \
# 3643         0xcacdf5  0x231d68      93.47     303211.00 2021-08-28
# 3644            Pixls  Carlini8       1.45        546.00 2020-09-14
# 3645         0x62bdc6  0xcacdf5      89.47     281077.00 2021-08-27
# 3646           Cyborg  0x62bdc6      82.00     256554.00 2021-08-27
# 3647         0x62bdc6    Cyborg      76.47     239956.00 2021-08-27
#
#       rarity_rank tipus          skin                    traits  traits_count  \
# 3643         7702  Male  Dark-skinned  Mohawk Dark, Muttonchops             2
# 3644         7702  Male  Dark-skinned  Mohawk Dark, Muttonchops             2
# 3645         7702  Male  Dark-skinned  Mohawk Dark, Muttonchops             2
# 3646         7702  Male  Dark-skinned  Mohawk Dark, Muttonchops             2
# 3647         7702  Male  Dark-skinned  Mohawk Dark, Muttonchops             2
#
#      CurrentOwner  priceETH  Sold_count
# 3643     0x5E5BA6   3243.90          21
# 3644     0x5E5BA6    376.70          21
# 3645     0x5E5BA6   3273.58          21
# 3646     0x5E5BA6   3273.58          21
# 3647     0x5E5BA6   3273.58          21

# %%
sns.regplot(x=Punks_soldCount_df["rarity_rank"], y=Punks_soldCount_df["AmountDollar"])
# Out:
# <AxesSubplot:xlabel='rarity_rank', ylabel='AmountDollar'>

# %%
sns.set(rc={'figure.figsize':(10,6)})
sns.regplot(x=Punks_soldCount_df["traits_count"], y=Punks_soldCount_df["AmountDollar"])
# Out:
# <AxesSubplot:xlabel='traits_count', ylabel='AmountDollar'>

# %%
sns.regplot(x=Punks_soldCount_df["Sold_count"], y=Punks_soldCount_df["AmountDollar"])
# Out:
# <AxesSubplot:xlabel='Sold_count', ylabel='AmountDollar'>

# %%
Punks_soldCount_df[(Punks_soldCount_df.rarity_rank<500)&(Punks_soldCount_df.Sold_count>3)].groupby(["tipus","skin","traits_count"])["AmountDollar"].mean()
# Out:
# tipus   skin            traits_count
# Ape     Ape-skinned     1              349620.63
# Female  Albino-skinned  3              231597.75
#         Dark-skinned    2              107136.52
#                         3               49417.12
#                         4               91905.00
#                         9                 537.00
#         Light-skinned   3              371185.00
#                         4               88514.47
#                         5              125451.25
#         Mid-skinned     2                4592.00
#                         3              135304.21
#                         4               85698.33
#                         5              188744.75
# Male    Albino-skinned  3              116614.00
#         Dark-skinned    2               82136.86
#                         3               62621.75
#                         4                 340.80
#                         7              627648.50
#         Light-skinned   2              171158.33
#                         3              277501.25
#         Mid-skinned     2               10543.25
#                         3              180499.44
# Zombie  Zombie-skinned  3              333058.00
# Name: AmountDollar, dtype: float64

# %%
sns.boxplot( x=Punks_soldCount_df.rarity_rank<5000, y=Punks_soldCount_df["AmountDollar"] )
# Out:
# <AxesSubplot:xlabel='rarity_rank', ylabel='AmountDollar'>

# %%
sns.boxplot( x=Punks_soldCount_df.skin, y=Punks_soldCount_df["AmountDollar"] )
# Out:
# <AxesSubplot:xlabel='skin', ylabel='AmountDollar'>

# %%
sns.boxplot( x=Punks_soldCount_df.tipus, y=Punks_soldCount_df["AmountDollar"] )
# Out:
# <AxesSubplot:xlabel='tipus', ylabel='AmountDollar'>

# %%
sns.boxplot(x=Punks_soldCount_df.traits_count, y=Punks_soldCount_df["AmountDollar"])
# Out:
# <AxesSubplot:xlabel='traits_count', ylabel='AmountDollar'>

# %%
sns.boxplot(x=Punks_soldCount_df.Sold_count, y=Punks_soldCount_df["AmountDollar"])
plt.savefig('sold_count_plot.png')

# %%
Punks_soldCount_df.head()
# Out:
#    idTransaction idPropietario TypeTransaction  idCryptoPunk TransactionOwner  \
# 0           5849      0x285ce8            Sold           618         0xd7047c
# 1           5868      0x4c02b8            Sold           618         0x55e149
# 2           5871      0x55e149            Sold           618         0xf75fcd
# 3           5860      0x1919db            Sold           618         0x4c02b8
# 4           5852      0xd7047c            Sold           618         0x1919db
#
#    Reciever  AmountETH  AmountDollar       Date  rarity_rank   tipus  \
# 0  0x285ce8      97.25     381146.00 2021-09-04         8420  Female
# 1  0x4c02b8     133.99     434962.00 2021-08-29         8420  Female
# 2  0x55e149     120.00     389548.00 2021-08-29         8420  Female
# 3  0x1919db     100.00     338384.00 2021-08-31         8420  Female
# 4  0xd7047c      93.25     370183.00 2021-09-03         8420  Female
#
#            skin                       traits  traits_count CurrentOwner  \
# 0  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 1  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 2  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 3  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
# 4  Dark-skinned  Clown Eyes Green, Wild Hair             2     0xf75fcD
#
#    priceETH  Sold_count
# 0   3884.97           6
# 1   3222.16           6
# 2   3222.16           6
# 3   3430.74           6
# 4   3936.29           6

# %%
profits_df=Punks_soldCount_df.copy()
profits_df["profit"]=""
profits_df.tail()
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 18420         130652      zaphodok            Sold          8289
# 18421          82577     0x17e31b…            Sold          5519
# 18422          84980      0x717403            Sold          5670
# 18423         119340      0xc9f203            Sold          7615
# 18424         112399      0x3ab536            Sold          7227
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 18420         0x00d7c9   zaphodok       0.10         48.00 2018-07-18
# 18421         0x00d7c9  0x17e31b…       0.25         43.00 2019-09-01
# 18422             Zieg   0x717403       0.31        103.00 2017-11-15
# 18423         0x8234be   0xc9f203       0.11         55.00 2018-04-14
# 18424         0x00d7c9   0x3ab536       0.10         47.00 2018-07-04
#
#        rarity_rank   tipus           skin  \
# 18420         2110    Male    Mid-skinned
# 18421         6991    Male   Dark-skinned
# 18422          253  Female   Dark-skinned
# 18423         2768  Female  Light-skinned
# 18424         3922    Male  Light-skinned
#
#                                           traits  traits_count CurrentOwner  \
# 18420  Big Shades, Cigarette, Goat, Vampire Hair             4     0x6853a5
# 18421      Big Shades, Knitted Cap, Normal Beard             3     0x17E31b
# 18422               Orange Side, Welding Goggles             2     0x717403
# 18423                    Eye Mask, Straight Hair             2     0xC9f203
# 18424               Front Beard Dark, Police Cap             2     0x3Ab536
#
#        priceETH  Sold_count profit
# 18420    480.00           1
# 18421    169.72           1
# 18422    330.59           1
# 18423    502.52           1
# 18424    467.52           1

# %%
profits_df.head(50)
# Out:
#     idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 0            5849      0x285ce8            Sold           618
# 1            5868      0x4c02b8            Sold           618
# 2            5871      0x55e149            Sold           618
# 3            5860      0x1919db            Sold           618
# 4            5852      0xd7047c            Sold           618
# ..            ...           ...             ...           ...
# 45          72266      0x50dd57            Sold          4893
# 46          72289      0xad0bcc            Sold          4893
# 47          95011      0xd2c1a0            Sold          6275
# 48          95018       Pranksy            Sold          6275
# 49         108498      0x74be0a            Sold          6997
#
#    TransactionOwner  Reciever  AmountETH  AmountDollar       Date  \
# 0          0xd7047c  0x285ce8      97.25     381146.00 2021-09-04
# 1          0x55e149  0x4c02b8     133.99     434962.00 2021-08-29
# 2          0xf75fcd  0x55e149     120.00     389548.00 2021-08-29
# 3          0x4c02b8  0x1919db     100.00     338384.00 2021-08-31
# 4          0x1919db  0xd7047c      93.25     370183.00 2021-09-03
# ..              ...       ...        ...           ...        ...
# 45         0x62bdc6  0x50dd57      69.00     210753.00 2021-08-08
# 46         0x00d7c9  0xad0bcc       0.10         62.00 2018-06-03
# 47          Pranksy  0xd2c1a0    1320.00    5120000.00 2021-09-04
# 48         0xaff336   Pranksy    1000.00    3890000.00 2021-09-04
# 49         0x10f168  0x74be0a      97.19     376658.00 2021-09-04
#
#     rarity_rank   tipus            skin  \
# 0          8420  Female    Dark-skinned
# 1          8420  Female    Dark-skinned
# 2          8420  Female    Dark-skinned
# 3          8420  Female    Dark-skinned
# 4          8420  Female    Dark-skinned
# ..          ...     ...             ...
# 45         1650  Female    Dark-skinned
# 46         1650  Female    Dark-skinned
# 47          549  Zombie  Zombie-skinned
# 48          549  Zombie  Zombie-skinned
# 49         2621  Female    Dark-skinned
#
#                                                traits  traits_count  \
# 0                         Clown Eyes Green, Wild Hair             2
# 1                         Clown Eyes Green, Wild Hair             2
# 2                         Clown Eyes Green, Wild Hair             2
# 3                         Clown Eyes Green, Wild Hair             2
# 4                         Clown Eyes Green, Wild Hair             2
# ..                                                ...           ...
# 45                        Regular Shades, Wild Blonde             2
# 46                        Regular Shades, Wild Blonde             2
# 47                          Mohawk Dark, Shadow Beard             2
# 48                          Mohawk Dark, Shadow Beard             2
# 49  Earring, Regular Shades, Straight Hair Dark, H...             4
#
#    CurrentOwner  priceETH  Sold_count profit
# 0      0xf75fcD   3884.97           6
# 1      0xf75fcD   3222.16           6
# 2      0xf75fcD   3222.16           6
# 3      0xf75fcD   3430.74           6
# 4      0xf75fcD   3936.29           6
# ..          ...       ...         ...    ...
# 45     0x91338c   3012.07           6
# 46     0x91338c    619.08           6
# 47     0x9f41a4   3884.97           2
# 48     0x9f41a4   3884.97           2
# 49     0x577eBC   3884.97           3
#
# [50 rows x 18 columns]

# %%
profits_df.sort_values(['idCryptoPunk', 'Date'], inplace=True, ascending=[True, False])
profits_df.head(50)
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 2389              22      0xe08c32            Sold             0
# 2390              30      0xa0a59c            Sold             0
# 2391              37      0x00d7c9            Sold             0
# 3892              52      0xcf6165            Sold             1
# 3893              78      GoWest23            Sold             1
# 3894              96      0xa0a59c            Sold             1
# 11904            300     0x7c00c9…            Sold            14
# 11905            302      0x582fa7            Sold            14
# 11906            306      0xd8e806            Sold            14
# 11055            411      0x6611fe            Sold            33
# 11367            492      0xe20388            Sold            53
# 11368            520           jmg            Sold            53
# 11366            526      0xdcf227            Sold            53
# 11982            732     TokenAng…            Sold            89
# 11983            735           jmg            Sold            89
# 11981            763      0xd8e806            Sold            89
# 11923            923      0x582fa7            Sold           116
# 11924            932      0xd8e806            Sold           116
# 16393            953      0x9179de            Sold           118
# 16394            957      0x436a4a            Sold           118
# 12487           1007      0x8bfe24            Sold           124
# 12486           1009      0xf25e63            Sold           124
# 12485           1012      0x84c920            Sold           124
# 14057           1056      0xd049b3            Sold           138
# 14056           1064      0x1919db            Sold           138
# 14058           1073      0xdde0b7            Sold           138
# 14059           1076      0x380236            Sold           138
# 14060           1078      0x753b20            Sold           138
# 14061           1080      0xd4442b            Sold           138
# 7818            1090      0xf605c6            Sold           139
# 7821            1094      0x7c0830            Sold           139
# 7819            1099      0x60d4b1            Sold           139
# 7820            1101      0xaedaf3            Sold           139
# 16606           1110      0x78e6fe            Sold           141
# 16605           1121      0xd79165            Sold           141
# 9784            1139      0x9cb8c1            Sold           143
# 9783            1147      0x09d408            Sold           143
# 9782            1154      MrTpunks            Sold           143
# 15393           1207     Michel_M…            Sold           155
# 15394           1213         DANNY            Sold           155
# 15395           1216     Michel_M…            Sold           155
# 920             1235      0x24f270            Sold           160
# 918             1245      0x565496            Sold           160
# 919             1251      0x54d7f9            Sold           160
# 7822            1262      0xf605c6            Sold           161
# 7823            1266      0x62bdc6            Sold           161
# 7825            1287     jawns.et…            Sold           161
# 7824            1293      0x3634f3            Sold           161
# 16938           1317     TokenAng…            Sold           168
# 6132            1327      0xcfc505            Sold           169
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 2389          0xf5099e   0xe08c32      25.00       2822.00 2018-11-30
# 2390          0x00d7c9   0xa0a59c       1.60        386.00 2017-07-07
# 2391          0xc352b5   0x00d7c9       0.98        320.00 2017-06-23
# 3892         EliteCat…   0xcf6165      60.00      36305.00 2020-11-30
# 3893          0xf5099e   GoWest23      31.00       5155.00 2019-04-06
# 3894          0xc352b5   0xa0a59c       0.42        107.00 2017-06-26
# 11904         0x582fa7  0x7c00c9…       2.50        234.00 2018-12-07
# 11905         0xd8e806   0x582fa7       1.85        351.00 2017-07-17
# 11906         0xc352b5   0xd8e806       0.90        185.00 2017-07-13
# 11055         0xc352b5   0x6611fe       0.51        105.00 2017-07-10
# 11367         0xb813c6   0xe20388     129.99     432676.00 2021-08-23
# 11368         0xdcf227        jmg      22.00      42803.00 2021-02-19
# 11366         0xc352b5   0xdcf227      20.00      26612.00 2021-02-01
# 11982              jmg  TokenAng…      19.99       6898.00 2020-09-06
# 11983        pablopun…        jmg      20.00       4138.00 2020-05-28
# 11981         0xc352b5   0xd8e806       1.50        336.00 2017-07-12
# 11923         0xd8e806   0x582fa7       2.40        456.00 2017-07-17
# 11924         0xc352b5   0xd8e806       1.20        229.00 2017-07-11
# 16393         0x436a4a   0x9179de      20.45      69259.00 2021-05-04
# 16394         0x394547   0x436a4a      20.25      36230.00 2021-03-11
# 12487         0xf25e63   0x8bfe24      17.00      41859.00 2021-06-10
# 12486         0x84c920   0xf25e63      19.90      34519.00 2021-03-08
# 12485         0x51636d   0x84c920      15.00      25709.00 2021-03-07
# 14057         0x1919db   0xd049b3      57.99     194425.00 2021-08-23
# 14056         0x22fa8c   0x1919db      42.00     136140.00 2021-08-15
# 14058         0x380236   0xdde0b7      15.95      33761.00 2021-04-06
# 14059         0x753b20   0x380236      15.25      32364.00 2021-04-06
# 14060         0xd4442b   0x753b20      14.50      30548.00 2021-04-06
# 14061         0xf98a39   0xd4442b      14.00      29199.00 2021-04-06
# 7818          0x7c0830   0xf605c6      87.90     275193.00 2021-08-27
# 7821          0x60d4b1   0x7c0830      45.99     145366.00 2021-08-19
# 7819          0xaedaf3   0x60d4b1      45.99     128595.00 2021-08-05
# 7820         iportfol…   0xaedaf3      24.99      44945.00 2021-03-11
# 16606         0x285be4   0x78e6fe      39.50      86752.00 2021-07-27
# 16605         0x50dd57   0xd79165      33.99      71411.00 2021-04-06
# 9784          0x09d408   0x9cb8c1     180.00     418676.00 2021-07-04
# 9783          MrTpunks   0x09d408     165.00     312721.00 2021-03-14
# 9782          0xc352b5   MrTpunks       6.50       1041.00 2020-01-25
# 15393         0x1da533  Michel_M…      25.00      32621.00 2021-01-31
# 15394        Michel_M…      DANNY      12.00       4253.00 2020-09-09
# 15395         0xc352b5  Michel_M…       7.00       2708.00 2020-08-26
# 920           0x565496   0x24f270      53.00     127403.00 2021-04-21
# 918           0x54d7f9   0x565496      40.00      64338.00 2021-03-03
# 919           0xc352b5   0x54d7f9      30.00      58686.00 2021-02-19
# 7822          0x62bdc6   0xf605c6      89.47     282907.00 2021-08-27
# 7823          0x88bc3e   0x62bdc6      77.00     240179.00 2021-08-27
# 7825          0x3634f3  jawns.et…      22.21      60124.00 2021-04-28
# 7824           Pranksy   0x3634f3      17.00      35762.00 2021-04-05
# 16938         0xc352b5  TokenAng…      25.00      29367.00 2021-01-06
# 6132           laz.eth   0xcfc505      56.00     137731.00 2021-07-31
#
#        rarity_rank   tipus           skin  \
# 2389          2023  Female    Mid-skinned
# 2390          2023  Female    Mid-skinned
# 2391          2023  Female    Mid-skinned
# 3892          4352    Male   Dark-skinned
# 3893          4352    Male   Dark-skinned
# 3894          4352    Male   Dark-skinned
# 11904          155  Female   Dark-skinned
# 11905          155  Female   Dark-skinned
# 11906          155  Female   Dark-skinned
# 11055         7635    Male  Light-skinned
# 11367         2825  Female  Light-skinned
# 11368         2825  Female  Light-skinned
# 11366         2825  Female  Light-skinned
# 11982          125  Female   Dark-skinned
# 11983          125  Female   Dark-skinned
# 11981          125  Female   Dark-skinned
# 11923          220  Female   Dark-skinned
# 11924          220  Female   Dark-skinned
# 16393         9954  Female  Light-skinned
# 16394         9954  Female  Light-skinned
# 12487         6760    Male    Mid-skinned
# 12486         6760    Male    Mid-skinned
# 12485         6760    Male    Mid-skinned
# 14057         9806    Male  Light-skinned
# 14056         9806    Male  Light-skinned
# 14058         9806    Male  Light-skinned
# 14059         9806    Male  Light-skinned
# 14060         9806    Male  Light-skinned
# 14061         9806    Male  Light-skinned
# 7818          7470    Male    Mid-skinned
# 7821          7470    Male    Mid-skinned
# 7819          7470    Male    Mid-skinned
# 7820          7470    Male    Mid-skinned
# 16606         6115    Male   Dark-skinned
# 16605         6115    Male   Dark-skinned
# 9784            91    Male  Light-skinned
# 9783            91    Male  Light-skinned
# 9782            91    Male  Light-skinned
# 15393         2455    Male   Dark-skinned
# 15394         2455    Male   Dark-skinned
# 15395         2455    Male   Dark-skinned
# 920            612  Female    Mid-skinned
# 918            612  Female    Mid-skinned
# 919            612  Female    Mid-skinned
# 7822          9452  Female   Dark-skinned
# 7823          9452  Female   Dark-skinned
# 7825          9452  Female   Dark-skinned
# 7824          9452  Female   Dark-skinned
# 16938         1880  Female  Light-skinned
# 6132          1299  Female    Mid-skinned
#
#                                                   traits  traits_count  \
# 2389   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2390   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2391   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 3892                                       Mohawk, Smile             2
# 3893                                       Mohawk, Smile             2
# 3894                                       Mohawk, Smile             2
# 11904                   Hot Lipstick, Pilot Helmet, Pipe             3
# 11905                   Hot Lipstick, Pilot Helmet, Pipe             3
# 11906                   Hot Lipstick, Pilot Helmet, Pipe             3
# 11055                                         Peak Spike             1
# 11367                          Big Shades, Straight Hair             2
# 11368                          Big Shades, Straight Hair             2
# 11366                          Big Shades, Straight Hair             2
# 11982                                             Choker             1
# 11983                                             Choker             1
# 11981                                             Choker             1
# 11923    Black Lipstick, Clown Eyes Blue, Earring, Tiara             4
# 11924    Black Lipstick, Clown Eyes Blue, Earring, Tiara             4
# 16393                            Bandana, Black Lipstick             2
# 16394                            Bandana, Black Lipstick             2
# 12487            Earring, Normal Beard Black, Peak Spike             3
# 12486            Earring, Normal Beard Black, Peak Spike             3
# 12485            Earring, Normal Beard Black, Peak Spike             3
# 14057                   Horned Rim Glasses, Stringy Hair             2
# 14056                   Horned Rim Glasses, Stringy Hair             2
# 14058                   Horned Rim Glasses, Stringy Hair             2
# 14059                   Horned Rim Glasses, Stringy Hair             2
# 14060                   Horned Rim Glasses, Stringy Hair             2
# 14061                   Horned Rim Glasses, Stringy Hair             2
# 7818                                   Do-rag, Eye Patch             2
# 7821                                   Do-rag, Eye Patch             2
# 7819                                   Do-rag, Eye Patch             2
# 7820                                   Do-rag, Eye Patch             2
# 16606                    3D Glasses, Chinstrap, Headband             3
# 16605                    3D Glasses, Chinstrap, Headband             3
# 9784                          Beanie, Horned Rim Glasses             2
# 9783                          Beanie, Horned Rim Glasses             2
# 9782                          Beanie, Horned Rim Glasses             2
# 15393                       Clown Hair Green, Clown Nose             2
# 15394                       Clown Hair Green, Clown Nose             2
# 15395                       Clown Hair Green, Clown Nose             2
# 920           Clown Eyes Blue, Pigtails, Purple Lipstick             3
# 918           Clown Eyes Blue, Pigtails, Purple Lipstick             3
# 919           Clown Eyes Blue, Pigtails, Purple Lipstick             3
# 7822                           Frumpy Hair, Hot Lipstick             2
# 7823                           Frumpy Hair, Hot Lipstick             2
# 7825                           Frumpy Hair, Hot Lipstick             2
# 7824                           Frumpy Hair, Hot Lipstick             2
# 16938          Blonde Bob, Blue Eye Shadow, Silver Chain             3
# 6132       Hot Lipstick, Regular Shades, Wild White Hair             3
#
#       CurrentOwner  priceETH  Sold_count profit
# 2389      0xE08c32    113.77           3
# 2390      0xE08c32    238.38           3
# 2391      0xE08c32    324.37           3
# 3892      0xB88F61    615.92           3
# 3893      0xB88F61    165.55           3
# 3894      0xB88F61    251.30           3
# 11904     0x7C00c9     93.27           3
# 11905     0x7C00c9    190.16           3
# 11906     0x7C00c9    205.00           3
# 11055     0x6611fE    202.00           1
# 11367     0xe20388   3319.49           3
# 11368     0xe20388   1955.59           3
# 11366     0xe20388   1373.40           3
# 11982     0x78f026    353.49           3
# 11983     0x78f026    220.18           3
# 11981     0x78f026    223.92           3
# 11923     0x9Ef55a    190.16           2
# 11924     0x9Ef55a    188.63           2
# 16393     0x9179de   3286.71           2
# 16394     0x9179de   1825.79           2
# 12487     0xEDd776   2469.97           3
# 12486     0xEDd776   1831.49           3
# 12485     0xEDd776   1728.10           3
# 14057     0xD049b3   3319.49           6
# 14056     0xD049b3   3308.87           6
# 14058     0xD049b3   2111.53           6
# 14059     0xD049b3   2111.53           6
# 14060     0xD049b3   2111.53           6
# 14061     0xD049b3   2111.53           6
# 7818      0x7C0830   3273.58           4
# 7821      0x7C0830   3184.82           4
# 7819      0x7C0830   2827.21           4
# 7820      0x7C0830   1825.79           4
# 16606     0x78E6Fe   2300.22           2
# 16605     0x78E6Fe   2111.53           2
# 9784      0x9Cb8C1   2323.22           3
# 9783      0x9Cb8C1   1849.06           3
# 9782      0x9Cb8C1    160.44           3
# 15393     0xca5E7f   1312.73           3
# 15394     0xca5E7f    351.10           3
# 15395     0xca5E7f    385.96           3
# 920       0x565496   2360.81           3
# 918       0x565496   1571.05           3
# 919       0x565496   1955.59           3
# 7822      0x88bC3E   3273.58           4
# 7823      0x88bC3E   3273.58           4
# 7825      0x88bC3E   2746.54           4
# 7824      0x88bC3E   2106.41           4
# 16938     0x78f026   1207.77           1
# 6132      0xcfc505   2532.19           4

# %%
order_profits_df=profits_df.copy()

# %%
order_profits_df.reset_index(drop=True)
order_profits_df
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 2389              22      0xe08c32            Sold             0
# 2390              30      0xa0a59c            Sold             0
# 2391              37      0x00d7c9            Sold             0
# 3892              52      0xcf6165            Sold             1
# 3893              78      GoWest23            Sold             1
# ...              ...           ...             ...           ...
# 15625         161224      0x0e4437            Sold          9997
# 15624         161238          gaus            Sold          9997
# 1048          161256     0xef764b…            Sold          9998
# 1047          161275      0xcfd9cc            Sold          9998
# 1049          161279     TokenAng…            Sold          9998
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 2389          0xf5099e   0xe08c32      25.00       2822.00 2018-11-30
# 2390          0x00d7c9   0xa0a59c       1.60        386.00 2017-07-07
# 2391          0xc352b5   0x00d7c9       0.98        320.00 2017-06-23
# 3892         EliteCat…   0xcf6165      60.00      36305.00 2020-11-30
# 3893          0xf5099e   GoWest23      31.00       5155.00 2019-04-06
# ...                ...        ...        ...           ...        ...
# 15625         3van.eth   0x0e4437      99.99     169770.00 2021-02-08
# 15624           TJ2010       gaus      59.00      21062.00 2020-09-27
# 1048          0xcfd9cc  0xef764b…     110.00     346575.00 2021-08-11
# 1047         TokenAng…   0xcfd9cc      38.00      61170.00 2021-03-03
# 1049         cyberpnk…  TokenAng…      15.00       9499.00 2020-12-27
#
#        rarity_rank   tipus            skin  \
# 2389          2023  Female     Mid-skinned
# 2390          2023  Female     Mid-skinned
# 2391          2023  Female     Mid-skinned
# 3892          4352    Male    Dark-skinned
# 3893          4352    Male    Dark-skinned
# ...            ...     ...             ...
# 15625          498  Zombie  Zombie-skinned
# 15624          498  Zombie  Zombie-skinned
# 1048          1271  Female     Mid-skinned
# 1047          1271  Female     Mid-skinned
# 1049          1271  Female     Mid-skinned
#
#                                                   traits  traits_count  \
# 2389   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2390   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2391   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 3892                                       Mohawk, Smile             2
# 3893                                       Mohawk, Smile             2
# ...                                                  ...           ...
# 15625                           Cap Forward, Front Beard             2
# 15624                           Cap Forward, Front Beard             2
# 1048   Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 1047   Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 1049   Black Lipstick, Clown Eyes Green, Wild White Hair             3
#
#       CurrentOwner  priceETH  Sold_count profit
# 2389      0xE08c32    113.77           3
# 2390      0xE08c32    238.38           3
# 2391      0xE08c32    324.37           3
# 3892      0xB88F61    615.92           3
# 3893      0xB88F61    165.55           3
# ...            ...       ...         ...    ...
# 15625     0x944D32   1750.18           2
# 15624     0x944D32    357.23           2
# 1048      0xef764B   3163.66           3
# 1047      0xef764B   1571.05           3
# 1049      0xef764B    683.71           3
#
# [18425 rows x 18 columns]

# %%
order_profits_df=profits_df.sort_values(['idCryptoPunk', 'Date'], ascending=[True, False])
order_profits_df
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 2389              22      0xe08c32            Sold             0
# 2390              30      0xa0a59c            Sold             0
# 2391              37      0x00d7c9            Sold             0
# 3892              52      0xcf6165            Sold             1
# 3893              78      GoWest23            Sold             1
# ...              ...           ...             ...           ...
# 15625         161224      0x0e4437            Sold          9997
# 15624         161238          gaus            Sold          9997
# 1048          161256     0xef764b…            Sold          9998
# 1047          161275      0xcfd9cc            Sold          9998
# 1049          161279     TokenAng…            Sold          9998
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 2389          0xf5099e   0xe08c32      25.00       2822.00 2018-11-30
# 2390          0x00d7c9   0xa0a59c       1.60        386.00 2017-07-07
# 2391          0xc352b5   0x00d7c9       0.98        320.00 2017-06-23
# 3892         EliteCat…   0xcf6165      60.00      36305.00 2020-11-30
# 3893          0xf5099e   GoWest23      31.00       5155.00 2019-04-06
# ...                ...        ...        ...           ...        ...
# 15625         3van.eth   0x0e4437      99.99     169770.00 2021-02-08
# 15624           TJ2010       gaus      59.00      21062.00 2020-09-27
# 1048          0xcfd9cc  0xef764b…     110.00     346575.00 2021-08-11
# 1047         TokenAng…   0xcfd9cc      38.00      61170.00 2021-03-03
# 1049         cyberpnk…  TokenAng…      15.00       9499.00 2020-12-27
#
#        rarity_rank   tipus            skin  \
# 2389          2023  Female     Mid-skinned
# 2390          2023  Female     Mid-skinned
# 2391          2023  Female     Mid-skinned
# 3892          4352    Male    Dark-skinned
# 3893          4352    Male    Dark-skinned
# ...            ...     ...             ...
# 15625          498  Zombie  Zombie-skinned
# 15624          498  Zombie  Zombie-skinned
# 1048          1271  Female     Mid-skinned
# 1047          1271  Female     Mid-skinned
# 1049          1271  Female     Mid-skinned
#
#                                                   traits  traits_count  \
# 2389   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2390   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2391   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 3892                                       Mohawk, Smile             2
# 3893                                       Mohawk, Smile             2
# ...                                                  ...           ...
# 15625                           Cap Forward, Front Beard             2
# 15624                           Cap Forward, Front Beard             2
# 1048   Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 1047   Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 1049   Black Lipstick, Clown Eyes Green, Wild White Hair             3
#
#       CurrentOwner  priceETH  Sold_count profit
# 2389      0xE08c32    113.77           3
# 2390      0xE08c32    238.38           3
# 2391      0xE08c32    324.37           3
# 3892      0xB88F61    615.92           3
# 3893      0xB88F61    165.55           3
# ...            ...       ...         ...    ...
# 15625     0x944D32   1750.18           2
# 15624     0x944D32    357.23           2
# 1048      0xef764B   3163.66           3
# 1047      0xef764B   1571.05           3
# 1049      0xef764B    683.71           3
#
# [18425 rows x 18 columns]

# %%
i=0

order_profits_df["profit_pcent"]=""

while i < len(order_profits_df)-1:
    if order_profits_df.idCryptoPunk.iloc[i+1] == order_profits_df.idCryptoPunk.iloc[i]:
        order_profits_df.profit.iloc[i]=order_profits_df.AmountDollar.iloc[i] - order_profits_df.AmountDollar.iloc[i+1] #the difference btwn two values in a column.
        order_profits_df.profit_pcent.iloc[i]=order_profits_df.profit.iloc[i]/order_profits_df.AmountDollar.iloc[i+1]
    else:
        order_profits_df.profit.iloc[i]= order_profits_df.AmountDollar.iloc[i]
        order_profits_df.profit_pcent.iloc[i]=0
    i+=1
    if i == len(order_profits_df)-1:
        print(i)
        order_profits_df.profit.iloc[i]= order_profits_df.AmountDollar.iloc[i]
        order_profits_df.profit_pcent.iloc[i]=0
order_profits_df
# Out:
# 18424
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 2389              22      0xe08c32            Sold             0
# 2390              30      0xa0a59c            Sold             0
# 2391              37      0x00d7c9            Sold             0
# 3892              52      0xcf6165            Sold             1
# 3893              78      GoWest23            Sold             1
# ...              ...           ...             ...           ...
# 15625         161224      0x0e4437            Sold          9997
# 15624         161238          gaus            Sold          9997
# 1048          161256     0xef764b…            Sold          9998
# 1047          161275      0xcfd9cc            Sold          9998
# 1049          161279     TokenAng…            Sold          9998
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 2389          0xf5099e   0xe08c32      25.00       2822.00 2018-11-30
# 2390          0x00d7c9   0xa0a59c       1.60        386.00 2017-07-07
# 2391          0xc352b5   0x00d7c9       0.98        320.00 2017-06-23
# 3892         EliteCat…   0xcf6165      60.00      36305.00 2020-11-30
# 3893          0xf5099e   GoWest23      31.00       5155.00 2019-04-06
# ...                ...        ...        ...           ...        ...
# 15625         3van.eth   0x0e4437      99.99     169770.00 2021-02-08
# 15624           TJ2010       gaus      59.00      21062.00 2020-09-27
# 1048          0xcfd9cc  0xef764b…     110.00     346575.00 2021-08-11
# 1047         TokenAng…   0xcfd9cc      38.00      61170.00 2021-03-03
# 1049         cyberpnk…  TokenAng…      15.00       9499.00 2020-12-27
#
#        rarity_rank   tipus            skin  \
# 2389          2023  Female     Mid-skinned
# 2390          2023  Female     Mid-skinned
# 2391          2023  Female     Mid-skinned
# 3892          4352    Male    Dark-skinned
# 3893          4352    Male    Dark-skinned
# ...            ...     ...             ...
# 15625          498  Zombie  Zombie-skinned
# 15624          498  Zombie  Zombie-skinned
# 1048          1271  Female     Mid-skinned
# 1047          1271  Female     Mid-skinned
# 1049          1271  Female     Mid-skinned
#
#                                                   traits  traits_count  \
# 2389   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2390   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2391   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 3892                                       Mohawk, Smile             2
# 3893                                       Mohawk, Smile             2
# ...                                                  ...           ...
# 15625                           Cap Forward, Front Beard             2
# 15624                           Cap Forward, Front Beard             2
# 1048   Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 1047   Black Lipstick, Clown Eyes Green, Wild White Hair             3
# 1049   Black Lipstick, Clown Eyes Green, Wild White Hair             3
#
#       CurrentOwner  priceETH  Sold_count    profit profit_pcent
# 2389      0xE08c32    113.77           3   2436.00         6.31
# 2390      0xE08c32    238.38           3     66.00         0.21
# 2391      0xE08c32    324.37           3    320.00            0
# 3892      0xB88F61    615.92           3  31150.00         6.04
# 3893      0xB88F61    165.55           3   5048.00        47.18
# ...            ...       ...         ...       ...          ...
# 15625     0x944D32   1750.18           2 148708.00         7.06
# 15624     0x944D32    357.23           2  21062.00            0
# 1048      0xef764B   3163.66           3 285405.00         4.67
# 1047      0xef764B   1571.05           3  51671.00         5.44
# 1049      0xef764B    683.71           3   9499.00            0
#
# [18425 rows x 19 columns]

# %%
order_profits_df.head(40)
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 2389              22      0xe08c32            Sold             0
# 2390              30      0xa0a59c            Sold             0
# 2391              37      0x00d7c9            Sold             0
# 3892              52      0xcf6165            Sold             1
# 3893              78      GoWest23            Sold             1
# ...              ...           ...             ...           ...
# 9784            1139      0x9cb8c1            Sold           143
# 9783            1147      0x09d408            Sold           143
# 9782            1154      MrTpunks            Sold           143
# 15393           1207     Michel_M…            Sold           155
# 15394           1213         DANNY            Sold           155
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 2389          0xf5099e   0xe08c32      25.00       2822.00 2018-11-30
# 2390          0x00d7c9   0xa0a59c       1.60        386.00 2017-07-07
# 2391          0xc352b5   0x00d7c9       0.98        320.00 2017-06-23
# 3892         EliteCat…   0xcf6165      60.00      36305.00 2020-11-30
# 3893          0xf5099e   GoWest23      31.00       5155.00 2019-04-06
# ...                ...        ...        ...           ...        ...
# 9784          0x09d408   0x9cb8c1     180.00     418676.00 2021-07-04
# 9783          MrTpunks   0x09d408     165.00     312721.00 2021-03-14
# 9782          0xc352b5   MrTpunks       6.50       1041.00 2020-01-25
# 15393         0x1da533  Michel_M…      25.00      32621.00 2021-01-31
# 15394        Michel_M…      DANNY      12.00       4253.00 2020-09-09
#
#        rarity_rank   tipus           skin  \
# 2389          2023  Female    Mid-skinned
# 2390          2023  Female    Mid-skinned
# 2391          2023  Female    Mid-skinned
# 3892          4352    Male   Dark-skinned
# 3893          4352    Male   Dark-skinned
# ...            ...     ...            ...
# 9784            91    Male  Light-skinned
# 9783            91    Male  Light-skinned
# 9782            91    Male  Light-skinned
# 15393         2455    Male   Dark-skinned
# 15394         2455    Male   Dark-skinned
#
#                                                   traits  traits_count  \
# 2389   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2390   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 2391   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 3892                                       Mohawk, Smile             2
# 3893                                       Mohawk, Smile             2
# ...                                                  ...           ...
# 9784                          Beanie, Horned Rim Glasses             2
# 9783                          Beanie, Horned Rim Glasses             2
# 9782                          Beanie, Horned Rim Glasses             2
# 15393                       Clown Hair Green, Clown Nose             2
# 15394                       Clown Hair Green, Clown Nose             2
#
#       CurrentOwner  priceETH  Sold_count    profit profit_pcent
# 2389      0xE08c32    113.77           3   2436.00         6.31
# 2390      0xE08c32    238.38           3     66.00         0.21
# 2391      0xE08c32    324.37           3    320.00            0
# 3892      0xB88F61    615.92           3  31150.00         6.04
# 3893      0xB88F61    165.55           3   5048.00        47.18
# ...            ...       ...         ...       ...          ...
# 9784      0x9Cb8C1   2323.22           3 105955.00         0.34
# 9783      0x9Cb8C1   1849.06           3 311680.00       299.40
# 9782      0x9Cb8C1    160.44           3   1041.00            0
# 15393     0xca5E7f   1312.73           3  28368.00         6.67
# 15394     0xca5E7f    351.10           3   1545.00         0.57
#
# [40 rows x 19 columns]

# %%
order_profits_df.to_csv('order_profits_df.csv')

# %%
order_profits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18425 entries, 2389 to 1049
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   idTransaction     18425 non-null  int64
#  1   idPropietario     18425 non-null  object
#  2   TypeTransaction   18425 non-null  object
#  3   idCryptoPunk      18425 non-null  int64
#  4   TransactionOwner  18425 non-null  object
#  5   Reciever          18425 non-null  object
#  6   AmountETH         18425 non-null  float64
#  7   AmountDollar      18425 non-null  float64
#  8   Date              18425 non-null  datetime64[ns]
#  9   rarity_rank       18425 non-null  int64
#  10  tipus             18425 non-null  object
#  11  skin              18425 non-null  object
#  12  traits            18425 non-null  object
#  13  traits_count      18425 non-null  int64
#  14  CurrentOwner      18425 non-null  object
#  15  priceETH          18425 non-null  float64
#  16  Sold_count        18425 non-null  int64
#  17  profit            18425 non-null  object
#  18  profit_pcent      18388 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(10)
# memory usage: 2.8+ MB

# %%
order_profits_df[(order_profits_df.profit_pcent!=0)].groupby(["tipus","skin","traits_count"])["profit"].sum()
# Out:
# tipus   skin            traits_count
# Alien   Alien-skinned   1               8337635.00
#                         3               7555012.00
# Ape     Ape-skinned     1               2863329.99
#                         2               8544143.00
# Female  Albino-skinned  0               1029143.00
#                         1                391225.00
#                         2               5519177.01
#                         3               4239136.00
#                         4               1751282.00
#                         5               1777509.00
#                         6                    68.00
#         Dark-skinned    1               1237713.00
#                         2              19072624.00
#                         3              14343345.01
#                         4               5553997.99
#                         5               3102608.00
#                         6                509169.00
#                         7                 84812.00
#                         9                   556.00
#         Light-skinned   1                741529.00
#                         2              14783624.00
#                         3              18878054.00
#                         4               7801610.99
#                         5               2276985.00
#                         6                630871.00
#         Mid-skinned     1               1830842.00
#                         2              14238118.00
#                         3              20954924.00
#                         4               6553898.00
#                         5               2752119.00
#                         6                141306.00
#                         7                157106.00
# Male    Albino-skinned  0                134913.00
#                         1               1115068.00
#                         2              12692941.02
#                         3              11180497.00
#                         4               3062100.00
#                         5                634790.00
#         Dark-skinned    1                539782.00
#                         2              35580976.00
#                         3              41504920.99
#                         4              12511118.00
#                         5               2001714.00
#                         6               2366171.00
#                         7               1805332.00
#         Light-skinned   1               1252673.00
#                         2              36952605.99
#                         3              39228729.98
#                         4              14821587.00
#                         5               5505755.00
#                         6                387183.00
#         Mid-skinned     0                  2538.00
#                         1                907020.00
#                         2              29138727.00
#                         3              41922618.00
#                         4              10925921.00
#                         5               3253898.00
#                         6                  8751.00
#                         7                124571.00
# Zombie  Zombie-skinned  1               4319327.00
#                         2               8608358.00
#                         3               8805140.00
#                         4               1369289.00
# Name: profit, dtype: float64

# %%
order_profits_df.columns
# Out:
# Index(['idTransaction', 'idPropietario', 'TypeTransaction', 'idCryptoPunk',
#        'TransactionOwner', 'Reciever', 'AmountETH', 'AmountDollar', 'Date',
#        'rarity_rank', 'tipus', 'skin', 'traits', 'traits_count',
#        'CurrentOwner', 'priceETH', 'Sold_count', 'profit', 'profit_pcent'],
#       dtype='object')

# %%
idx_max=order_profits_df.groupby(["idCryptoPunk"])['idTransaction'].transform(min)==order_profits_df['idTransaction']
last_orders_df=pd.DataFrame(order_profits_df[idx_max])
last_orders_df
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 2389              22      0xe08c32            Sold             0
# 3892              52      0xcf6165            Sold             1
# 11904            300     0x7c00c9…            Sold            14
# 11055            411      0x6611fe            Sold            33
# 11367            492      0xe20388            Sold            53
# ...              ...           ...             ...           ...
# 3739          161119     keyboard…            Sold          9982
# 17921         161155      0x7760e0            Sold          9989
# 14083         161165      0x3689df            Sold          9990
# 15625         161224      0x0e4437            Sold          9997
# 1048          161256     0xef764b…            Sold          9998
#
#       TransactionOwner   Reciever  AmountETH  AmountDollar       Date  \
# 2389          0xf5099e   0xe08c32      25.00       2822.00 2018-11-30
# 3892         EliteCat…   0xcf6165      60.00      36305.00 2020-11-30
# 11904         0x582fa7  0x7c00c9…       2.50        234.00 2018-12-07
# 11055         0xc352b5   0x6611fe       0.51        105.00 2017-07-10
# 11367         0xb813c6   0xe20388     129.99     432676.00 2021-08-23
# ...                ...        ...        ...           ...        ...
# 3739         shilpixe…  keyboard…     149.00     481088.00 2021-08-28
# 17921             Zieg   0x7760e0       0.30        140.00 2017-11-28
# 14083         0xddfdcb   0x3689df       0.01          0.00 2021-08-15
# 15625         3van.eth   0x0e4437      99.99     169770.00 2021-02-08
# 1048          0xcfd9cc  0xef764b…     110.00     346575.00 2021-08-11
#
#        rarity_rank   tipus            skin  \
# 2389          2023  Female     Mid-skinned
# 3892          4352    Male    Dark-skinned
# 11904          155  Female    Dark-skinned
# 11055         7635    Male   Light-skinned
# 11367         2825  Female   Light-skinned
# ...            ...     ...             ...
# 3739          8012  Female   Light-skinned
# 17921          186  Female    Dark-skinned
# 14083         9186    Male  Albino-skinned
# 15625          498  Zombie  Zombie-skinned
# 1048          1271  Female     Mid-skinned
#
#                                                   traits  traits_count  \
# 2389   Blonde Bob, Earring, Green Eye Shadow, Hidden ...             4
# 3892                                       Mohawk, Smile             2
# 11904                   Hot Lipstick, Pilot Helmet, Pipe             3
# 11055                                         Peak Spike             1
# 11367                          Big Shades, Straight Hair             2
# ...                                                  ...           ...
# 3739           Earring, Stringy Hair, VR, Hidden Earring             4
# 17921              Cigarette, Hot Lipstick, Pilot Helmet             3
# 14083                         Horned Rim Glasses, Mohawk             2
# 15625                           Cap Forward, Front Beard             2
# 1048   Black Lipstick, Clown Eyes Green, Wild White Hair             3
#
#       CurrentOwner  priceETH  Sold_count    profit profit_pcent
# 2389      0xE08c32    113.77           3   2436.00         6.31
# 3892      0xB88F61    615.92           3  31150.00         6.04
# 11904     0x7C00c9     93.27           3   -117.00        -0.33
# 11055     0x6611fE    202.00           1    105.00            0
# 11367     0xe20388   3319.49           3 389873.00         9.11
# ...            ...       ...         ...       ...          ...
# 3739      0xc24F57   3243.90           1 481088.00            0
# 17921     0x7760E0    465.56           1    140.00            0
# 14083     0x3689Df   3308.87           2 -44981.00        -1.00
# 15625     0x944D32   1750.18           2 148708.00         7.06
# 1048      0xef764B   3163.66           3 285405.00         4.67
#
# [6343 rows x 19 columns]

# %%
last_orders_df.to_csv('last_orders_df.csv')

# %%
last_orders_df[last_orders_df.isna().any(axis=1)]
# Out:
#        idTransaction idPropietario TypeTransaction  idCryptoPunk  \
# 16857           3426      0x269616            Sold           402
# 3979           15178      0x269616            Sold          1417
# 11314          15471      0x269616            Sold          1436
# 5665           36930      0x269616            Sold          2791
# 4110           43161      0x269616            Sold          3143
# 17207          55180      0x269616            Sold          3789
# 10484          66339      0x269616            Sold          4493
# 10504          73023      0x269616            Sold          4933
# 14495          87284      0x269616            Sold          5821
# 7046           95039      0x269616            Sold          6276
# 9009          101913      0x269616            Sold          6641
# 2289          113589      0x269616            Sold          7281
# 7647          133320      0x269616            Sold          8444
# 16652         145934      0x269616            Sold          9146
# 7343          149812      0x269616            Sold          9364
# 15449         154406      0x269616            Sold          9620
#
#       TransactionOwner  Reciever  AmountETH  AmountDollar       Date  \
# 16857         0x0b8ee2  0x269616       0.00          0.00 2021-07-25
# 3979          0xaf93fc  0x269616       0.00          0.00 2021-07-30
# 11314         0xaf93fc  0x269616       0.00          0.00 2021-08-02
# 5665         ryley-to…  0x269616       0.00          0.00 2021-07-21
# 4110         ryley-to…  0x269616       0.00          0.00 2021-07-21
# 17207         0x0b8ee2  0x269616       0.00          0.00 2021-07-28
# 10484        ryley-to…  0x269616       0.00          0.00 2021-07-21
# 10504        ryley-to…  0x269616       0.00          0.00 2021-07-20
# 14495         0xaf93fc  0x269616       0.00          0.00 2021-08-02
# 7046          0xaf93fc  0x269616       0.00          0.00 2021-08-02
# 9009         wookie.e…  0x269616       0.00          0.00 2021-07-18
# 2289         ryley-to…  0x269616       0.00          0.00 2021-07-21
# 7647          0xaf93fc  0x269616       0.00          0.00 2021-08-02
# 16652         0x0b8ee2  0x269616       0.00          0.00 2021-07-27
# 7343          foul.eth  0x269616       0.00          0.00 2021-07-09
# 15449        ryley-to…  0x269616       0.00          0.00 2021-07-19
#
#        rarity_rank   tipus           skin  \
# 16857         5129    Male   Dark-skinned
# 3979          9766  Female   Dark-skinned
# 11314         9272    Male   Dark-skinned
# 5665          5578    Male   Dark-skinned
# 4110          5479    Male   Dark-skinned
# 17207         9282  Female   Dark-skinned
# 10484         7359    Male   Dark-skinned
# 10504         6035    Male    Mid-skinned
# 14495         8582  Female    Mid-skinned
# 7046          7581    Male   Dark-skinned
# 9009          6049    Male  Light-skinned
# 2289          8526    Male   Dark-skinned
# 7647          7380    Male   Dark-skinned
# 16652         5155    Male  Light-skinned
# 7343          5564    Male   Dark-skinned
# 15449         5713  Female    Mid-skinned
#
#                                              traits  traits_count  \
# 16857                 Front Beard Dark, Mohawk Thin             2
# 3979                   Classic Shades, Stringy Hair             2
# 11314                                  Mohawk, Mole             2
# 5665                        Handlebars, Mohawk Thin             2
# 4110               Earring, Handlebars, Shaved Head             3
# 17207              Earring, Mohawk, Purple Lipstick             3
# 10484                            Goat, Stringy Hair             2
# 10504                Front Beard, Mohawk Dark, Mole             3
# 14495        Clown Eyes Blue, Earring, Stringy Hair             3
# 7046                              Mole, Shaved Head             2
# 9009              Earring, Front Beard, Mohawk Thin             3
# 2289        Cigarette, Clown Eyes Blue, Mohawk Thin             3
# 7647   Horned Rim Glasses, Muttonchops, Shaved Head             3
# 16652     Eye Patch, Front Beard Dark, Stringy Hair             3
# 7343                        Handlebars, Mohawk Dark             2
# 15449      Bandana, Black Lipstick, Blue Eye Shadow             3
#
#       CurrentOwner  priceETH  Sold_count profit profit_pcent
# 16857     0x269616   2189.79           5   0.00          NaN
# 3979      0x269616   2460.95           6   0.00          NaN
# 11314     0x269616   2608.04          10   0.00          NaN
# 5665      0x269616   1994.49           5   0.00          NaN
# 4110      0x269616   1994.49           7   0.00          NaN
# 17207     0x269616   2299.11           2   0.00          NaN
# 10484     0x269616   1994.49           7   0.00          NaN
# 10504     0x2A98FC   1786.07           5   0.00          NaN
# 14495     0x269616   2608.04           2   0.00          NaN
# 7046      0x269616   2608.04          14   0.00          NaN
# 9009      0x269616   1892.42           3   0.00          NaN
# 2289      0x269616   1994.49          12   0.00          NaN
# 7647      0x269616   2608.04           9   0.00          NaN
# 16652     0x269616   2300.22           3   0.00          NaN
# 7343      0x269616   2145.89           7   0.00          NaN
# 15449     0x269616   1818.07           4   0.00          NaN

# %%
order_profits_df.Sold_count.value_counts()
# Out:
# 2     2926
# 3     2883
# 4     2656
# 5     2145
# 1     2076
# 6     1680
# 7     1218
# 8      936
# 9      522
# 10     500
# 11     308
# 12     228
# 13     143
# 15      60
# 14      56
# 17      51
# 21      21
# 16      16
# Name: Sold_count, dtype: int64

# %%
pd.set_option('display.max_rows', 200)
punks_Soldgroupby=pd.DataFrame(order_profits_df[(order_profits_df.profit_pcent!=0)].groupby(["tipus","skin","traits_count","Sold_count"])["profit"].max())
punks_Soldgroupby
# Out:
#                                                   profit
# tipus  skin           traits_count Sold_count
# Alien  Alien-skinned  1            2          7577873.00
#                       3            2          7555012.00
# Ape    Ape-skinned    1            2             3986.00
#                                    3            69965.00
#                                    4          1536975.00
# ...                                                  ...
# Zombie Zombie-skinned 3            2          2800000.00
#                                    3           769590.00
#                                    4           781457.00
#                                    7          1987800.00
#                       4            3          1360930.00
#
# [341 rows x 1 columns]

# %%
pd.set_option('display.max_rows',30)
punks_Soldgroupby.to_csv('punks_Soldgroupby.csv')

# %%
order_profits_df.idCryptoPunk.nunique()
# Out:
# 6343

# %%
order_profits_df.duplicated().sum()
# Out:
# 0

# %%
order_profits_df.Date.nunique()
# Out:
# 1150

# %%
order_profits_df.skin.nunique()
# Out:
# 7

# %% [markdown]
# ## Machine Learning
